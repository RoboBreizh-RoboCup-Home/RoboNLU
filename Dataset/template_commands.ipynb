# %%
import random
import yaml
import msgpack
import numpy as np
from sklearn.utils import resample

# %%
# import sys
# sys.argv=['']
# del sys
# from api import cot

# %%
rule_path = './CommonRules.txt'
gram_path = './EGPSRGrammar.txt'

def open_text(path):
    with open(path, encoding='utf-8') as f:
        lst = [line.strip() for line in f if line != '\n' ]
    return lst

rule = open_text(rule_path)
gram = open_text(gram_path)
gram
# Out:
# ['; grammar name GPSR Grammar',
#  '; grammar tier High',
#  '$Main      = $task',
#  '$Main      = $polite $task',
#  '$Main      = $task $please',
#  '# Tasks',
#  '####################################################################',
#  '; Bring from description',
#  '$task      = $bringdesc',
#  '; Bring from/to storage',
#  '$task      = $store',
#  '; Bring to person matching description',
#  '$task      = bring the {object} to the $person in the $room',
#  '; Complex commands',
#  '$task      = $triple',
#  '$task      = $singleI, $single, and ($single | $singleSp)',
#  '$task      = $single, $singleI, and ($single | $singleSp)',
#  '$task      = $single, $single, and ($singleI | $singleSpI)',
#  '$task      = $doublelI, and ($single | $singleSp)',
#  '$task      = $doublel, and ($singleI | $singleSpI)',
#  '$task      = $singleI, $doubler',
#  '$task      = $single, $doublerI',
#  '; Count objects',
#  '$task      = $countobj',
#  '; Count people',
#  '$task      = tell me how many $people there are in the $room',
#  '$task      = tell me how many $peoplege in the $room',
#  '$task      = tell me how many $peopleR in the $room',
#  '$task      = tell me how many $ppl in the $room are $peopleDsc',
#  '; Describe person',
#  '$task      = $descper',
#  '; Describe object',
#  '$task      = $descobj',
#  '$task      = $retrieve',
#  '; Doors',
#  '$task      = open the (entrance | exit | corridor) door',
#  '$task      = close the (entrance | exit | corridor) door',
#  '; Find object',
#  '$task      = $vbfind the {sobject} in the {room}',
#  '; Follow & guide',
#  '$task      = $follow',
#  '$task      = $guide',
#  '; Greet person matching description',
#  '$task      = $greet the $person in the $room',
#  '; Host',
#  '$task      = offer something to (eat | drink) to all the $people in the $room',
#  '$task      = offer something to (eat | drink) to all the $peopleg in the $room',
#  '; Meet and greet a person',
#  '$task      = $mgreet {void meta:There is only one person at {beacon 1}}',
#  '; Pouring',
#  '$task      = $pour',
#  '; Serving',
#  '$task      = $serve',
#  '# count',
#  '####################################################################',
#  '$countobj  = tell $repwho how many $countwhat are in the {placement 1}',
#  '$countobj  = count the $countwhat at the {placement 1} and $report',
#  '$countwhat = ({category} items) | $color ( {object} | {category} objects )',
#  '$report    = $vbreport $repwho',
#  '# Describe object',
#  '####################################################################',
#  '$descobj  = describe the objects in the {placement} to $repwho',
#  '# Describe person',
#  '####################################################################',
#  '$descper  = tell me how the person $posture at the {beacon} looks like',
#  '$descper  = describe the person $posture at the {beacon} to me',
#  '$descper  = describe the person $posture at the {beacon} to the person at the {beacon}',
#  '$descper  = describe to me the person $posture at the {beacon}',
#  '# Bring from/to storage',
#  '####################################################################',
#  '$retrieve  = $vbdeliver me some {category} from the $storage',
#  '$store     = put the {object} into the $storage',
#  '$store     = pick up a {category} from the {placement} and put it into the $storage',
#  '# Bring from description',
#  '####################################################################',
#  '$bringdesc = $vbdeliver me the $bdwhat from the {placement 1}',
#  '$bringdesc = take the $bdwhat from the {placement 1} to the {placement 2}',
#  '$bringdesc = $vbdeliver me the {category} at the $rpos {placement 1}',
#  '$bringdesc = $vbdeliver me something in a $canpourin',
#  "$bringdesc = take the {category} at the {placement 1}'s $rpos to the {placement 2}",
#  '$bdwhat    = $desc (object | {category})',
#  '# Follow & guide',
#  '####################################################################',
#  '; Hard to find a person, easy to follow/guide',
#  '$follow    = $vbfollow the $fgwhor',
#  '$guide     = $vbguide the $fgwhor to the (exit | {room 2})',
#  '; Easy-to-find person, but hard to follow/guide',
#  '$follow    = $vbfollow the $fgwho $fbriefing',
#  '$guide     = $vbguide the person at the {beacon 1} to the (exit | {beacon 2}) $gbriefing',
#  '; Helpers',
#  '$fgwho    = person at the {beacon}',
#  '$fgwhor   = $person in the $room',
#  '$fbriefing= {void meta: The Professional Walker must leave the arena and walk through a crowd of at least 5 people who must not let the robot pass. Once the robot has re-encountered its operator, the Professional Walker must lead the robot to {room 2} }',
#  '$gbriefing= {void meta: The Professional Walker must, in any order: a) stop following the robot and head towards {beacon 3}, b) stop and wait there, and c) start walking very slow. }',
#  '$gbriefing= {void meta: All doors between {beacon 1} and the target location are closed, as well as all paths to get there are blocked. }',
#  '# Greet',
#  '####################################################################',
#  '$greet     = $vbgreet',
#  '$greet     = ((say hello) | (introduce yourself)) to',
#  '$mgreet    = $vbmeet {name} at the {beacon 1}, then (greet | find) {pron} in the $room',
#  '# People',
#  '####################################################################',
#  '$peopleR   = $ppl are $peopleDsc',
#  '$peopleDsc = $posture | {gesture}',
#  '$peopleDsc = wearing $outfitss',
#  '$peopleDsc = wearing $color',
#  '$people    = $ppl',
#  '$people    = $posture $ppl',
#  '$peopleg   = $ppl {gesture}',
#  '$peoplege  = $ppl are {gesture}',
#  '$people    = $ppl wearing $outfitss',
#  '$people    = $ppl dressed in $color',
#  '$posture   = standing | sitting | lying down',
#  '$ppl       = people | children | elders | men | women',
#  '# Person',
#  '####################################################################',
#  '$person    = child',
#  '$person    = $lpdesc (man | woman | person)',
#  '$person    = (man | woman | person) {gesture}',
#  '$person    = (man | woman | person) $rpdesc',
#  '$lpdesc    = tallest | smallest | oldest | youngest | slimmest | fattest',
#  '$rpdesc    = dressed in an $coloran $outfita',
#  '$rpdesc    = dressed in a $colora $outfita',
#  '$rpdesc    = wearing ($apparel | a $colora $outfita | an $coloran $outfita | ($colora | $coloran) $outfits)',
#  '$colora    = blue | yellow | black | white | red | gray',
#  '$coloran   = orange',
#  '$color     = blue | yellow | black | white | red | gray | orange',
#  '$outfits   = shoes | pants',
#  '$outfita   = (T-shirt) | shirt | blouse | sweater | coat | jacket',
#  '$outfitss  = shoes | pants | (T-shirts) | shirts | blouses | sweaters | coats | jackets',
#  '$apparel   = a hat | glasses | a necklace | a tie | earrings',
#  '# Pouring',
#  '####################################################################',
#  '$pour      = $vbdeliver me some $pourable in a $canpourin',
#  '$pour      = $vbpour some $pourable in a $canpourin',
#  '# Serving',
#  '####################################################################',
#  '$serve     = $vbplace a $tableware on the {placement} and a $cutlery $servewhere',
#  '$servewhere= ( on | in ) it',
#  '$servewhere= on its (left | right)',
#  '# What to say',
#  '####################################################################',
#  '$whattosay = something about yourself',
#  '$whattosay = the time',
#  '$whattosay = what day is (today | tomorrow)',
#  "$whattosay = your team's (name | country | affiliation)",
#  '$whattosay = the day of the (week | month)',
#  '$whattosay = whether you dream or not on electric sheep',
#  '$whattosay = a joke',
#  '####################################################################',
#  '#',
#  '# COMPLEX COMMANDS',
#  '#',
#  '####################################################################',
#  '# Triple task commands',
#  '####################################################################',
#  '$triple   = $findordI, and ($place | $deliver)',
#  '$triple   = $findord, and ($placeI | $deliverI)',
#  '$triple   = $findpdI, and $guideS',
#  '$triple   = $findpd, and $guideI',
#  '$triple   = $findprdI, and ($guideS | $followS)',
#  '$triple   = $findprd, and $guideI',
#  '# Double task commands',
#  '####################################################################',
#  '; go get it',
#  '$doubler  = $take, and ($place | $deliver)',
#  '$doublel  = $take, ($place | $deliver)',
#  '$doublerI = $take, and ($placeI | $deliverI)',
#  '$doublerI = $takeI, and ($place | $deliver)',
#  '$doublelI = $take, ($placeI | $deliverI)',
#  '$doublelI = $takeI, ($place | $deliver)',
#  ';find person or object',
#  '$doublel  = $findord',
#  '$doublel  = $findprd',
#  '$doublelI = $findordI',
#  '$doublelI = $findprdI',
#  '; find and follow',
#  '$doubler  = $findprs, and $followS',
#  '$doublel  = $findprs, $followS',
#  '$doublerI = $findprsI, and $followS',
#  '$doublelI = $findprsI, $followS',
#  '; find and guide',
#  '$doubler  = $findps, and $guideS',
#  '$doublel  = $findps, $guideS',
#  '$doublerI = $findps, and $guideI',
#  '$doublerI = $findpsI, and $guideS',
#  '$doublelI = $findps, $guideI',
#  '$doublelI = $findpsI, $guideS',
#  '# Single task commands',
#  '####################################################################',
#  '$single   = $findps',
#  '$single   = $findprs',
#  '$single   = $findors',
#  '$single   = $take',
#  '$single   = $mvobj',
#  '$singleSp = $vbspeak $whattosay',
#  '$singleSp = answer a {question}',
#  '$singleI  = $findpsI',
#  '$singleI  = $findprsI',
#  '$singleI  = $findorsI',
#  '$singleI  = $takeI',
#  '$singleI  = $mvobjI',
#  '$singleSpI= (speak | (say something)) {void meta: When asked, reply to the robot: "$whattosay" }',
#  '# Tasks',
#  '####################################################################',
#  '; Find object in room',
#  '$findord  = $vbgor to the {room}, $vbfind the {object}',
#  '$findors  = $vbfind a {object} in the {room}',
#  '$findordI = $vbgor to the {room}, $vbfind the {object?}',
#  '$findorsI = $vbfind (a | the) {object meta: Robot must place it on the {placement}}',
#  '; Take an object',
#  '$take     = $vbtake the {aobject} from the {placement}',
#  '$takeI    = $vbtake the {aobject? meta: Place to } from the {placement}',
#  '$takeI    = $vbtake the {aobject meta: Robot will find it on the {placement}}',
#  '; Place an object',
#  '$place    = $vbplace it on the {placement}',
#  '$placeI   = $vbplace it to the {placement?}',
#  ';move object to target',
#  '$mvobj    = $vbplace {object} on the {placement}',
#  '$mvobjI   = $vbplace the {object} in the {placement?}',
#  '$mvobjI   = $vbplace a {object? meta: place 3 objects of the same category at {placement 1}} on the {placement 1}',
#  '; Deliver an object',
#  '$deliver  = $vbdeliver it to (me | {name} at the {beacon})',
#  '$deliverI = $vbdeliver it to {name meta: {pron sub} is (sitting | standing | lying | waving ) at the {beacon}}',
#  '; Find people in location',
#  '$findpd   = $vbgopl to the {beacon}, $vbfind {name}',
#  '$findps   = $vbfind {name} at the {beacon}',
#  '$findpdI  = $vbgopl to the {beacon}, $vbfind {name meta: {pron sub} is (sitting | standing | lying | waving ). Place three people there}',
#  '$findpsI  = $vbfind {name meta: {pron sub} is (sitting | standing | lying | waving ) at the {beacon}}',
#  '; Find people in room',
#  '$findprd  = $vbgor to the {room}, $vbfind {name}',
#  '$findprs  = $vbfind {name} in the {room}',
#  '$findprdI = $vbgor to the {room}, $vbfind {name meta: {pron sub} is (sitting | standing | waving ). Place three people in the room}',
#  '$findprsI = $vbfind {name meta: {pron sub} is (sitting | standing | waving ) at the {room}}',
#  '; Follow people',
#  '$followS  = $vbfollow {pron}',
#  '; Guide people',
#  '$guideS   = $vbguide {pron} to the ( {room} | {beacon} | exit )',
#  '$guideI   = escort {pron} {void meta: Escort {pron} to the ( {room} | {beacon} | exit )}',
#  '####################################################################',
#  '#',
#  '# GENERAL RULES',
#  '#',
#  '####################################################################',
#  '# Macros',
#  '####################################################################',
#  '$canpourin = {object where canPourIn=true}',
#  '$pourable  = {object where canPour=true}',
#  '$cereal    = {object where Category="food" canPour=true}',
#  '$snack     = {object where Category="snacks"}',
#  '$fruit     = {object where fruit=true}',
#  '$drink     = {object where Category="drinks"}',
#  '$storage   = microwave | fridge | oven | {object special where canPlaceIn=true} on the {placement}',
#  '$tableware = {object where Category="tableware"}',
#  '$cutlery   = {object where Category="cutlery"}',
#  '$rpos      = left | right | center | middle bottom | top',
#  '$desc      = $color | biggest | smallest | tallest | (left-most) | (right-most)',
#  '$color     = blue | yellow | black | white | red | orange | gray',
#  '$repwho    = me',
#  '$room      = {room 1 meta: At least three people must be here}',
#  '# Polite',
#  '####################################################################',
#  '$polite = Please',
#  '$polite = Could you',
#  '$polite = Robot please',
#  '$polite = Could you please',
#  '$please = please',
#  '# Verbs',
#  '####################################################################',
#  '$vbdeliver = bring | deliver to | give | hand',
#  '$vbfind    = find | locate | spot | pinpoint | look for',
#  '$vbfollow  = follow | ((come | go) (behind | after)) | accompany',
#  '$vbgopl    = go | navigate',
#  '$vbgor     = $vbgopl | enter',
#  '$vbgreet   = greet | salute | handshake',
#  '$vbguide   = guide | escort | take | lead | accompany | conduct',
#  '$vbmeet    = meet | contact | (get to know) | (get acquainted with)',
#  '$vbplace   = put | place | leave | set',
#  '$vbpour    = pour | serve',
#  '$vbreport  = inform | report to',
#  '$vbspeak   = tell | say',
#  '$vbtake    = get | grasp | take | retrieve | pick up']

# %%
rule
# Out:
# ['#',
#  '# This grammar file has no main, therefore, cannot be loaded',
#  '# standalone. Import using:',
#  '# ; import common.txt',
#  '#',
#  '# The following rules must be defined in the importer',
#  '# ; An object type',
#  '# $object',
#  '# ; Rule for finding a specific (named) person',
#  '# $findp',
#  '# ; A named or described person in the given place',
#  '# $whowhere',
#  '#',
#  '; grammar name Common',
#  '##############################################################################',
#  '#',
#  '# Manipulation',
#  '#',
#  '##############################################################################',
#  '$deliver  = $take to the {placement 2}',
#  '$deliver  = $vbplace the $object on the {placement 2}',
#  '$deliver  = $vbbring me the $object',
#  '$deliver  = $vbdeliver the $object to $someone',
#  '$deliver  = $takefrom to the {placement 2}',
#  '$deliver  = $goplace, $vbfind the $object, and ($delivme | $delivat)',
#  '$deliver  = $goplace, $vbfind the $object, and $place',
#  '##############################################################################',
#  '#',
#  '# Find people',
#  '#',
#  '##############################################################################',
#  '$fndppl   = $talk to $whowhere',
#  '$fndppl   = $findp in the {room} and $talk',
#  '$fndppl   = $goroom, $findp, and $talk',
#  '##############################################################################',
#  '#',
#  '# Find objects',
#  '#',
#  '##############################################################################',
#  '$fndobj   = Tell me how many $object there are on the {placement}',
#  '$fndobj   = $vbfind the $object in the {room}',
#  '##############################################################################',
#  '#',
#  '# Follow people',
#  '#',
#  '##############################################################################',
#  '$follow   = $vbfollow {name 1} from the {beacon 1} to the {room 2}',
#  '$follow   = meet {name 1} at the {beacon 1} and $vbfollow {pron} $fllwdest',
#  '$follow   = $gobeacon, meet {name 1}, and $vbfollow {pron} $fllwhdst',
#  '$fllmeet  = meet {name 1} | find a person',
#  '$fllwdest = (to the {room 2}) | $fllwhdst',
#  '$fllwhdst = {void meta: Follow {name 1} to the {room 2}}',
#  '##############################################################################',
#  '#',
#  '# Guide people',
#  '#',
#  '##############################################################################',
#  '$guide    = $gdcmd $gdmeta',
#  '$gdcmd    = $vbguide {name 1} from the {beacon 1} to the {beacon 2}',
#  '$gdcmd    = meet {name 1} at the {beacon 1} and $guideto',
#  '$gdcmd    = $gobeacon, meet {name 1}, and $guideto',
#  '$gdcmd    = $vbguide {name 1} to the {beacon 2}, $gdwhere',
#  '$guideto  = $vbguide {pron} to the {beacon 2}',
#  '$gdwhere  = you (may | can | will) find {pron} at the {beacon 1}',
#  '$gdmeta   = {void meta: The person being guided must deviate when indicated by the referee before reaching the {beacon 2}}',
#  '##############################################################################',
#  '#',
#  '# Rules',
#  '#',
#  '##############################################################################',
#  '; People',
#  '$someone  = me | $whowhere',
#  '; Place an object',
#  '$place    = $vbplace it on the {placement 2}',
#  '; Object properties',
#  '$oprop    = biggest | largest | smallest | heaviest | lightest | thinnest',
#  '; Navigating',
#  '$goplace  = $vbgopl to the {placement 1}',
#  '$gobeacon = $vbgopl to the {beacon 1}',
#  '$goroom   = $vbgopl to the {room 1}',
#  '; Take an object',
#  '$take     = $vbtake the $object',
#  '$takefrom = $take from the {placement 1}',
#  '; Deliver an object',
#  '$delivme  = $vbdeliver it to me',
#  '$delivto  = $vbdeliver it to {name}',
#  '$delivat  = $vbdeliver it to {name} at the {beacon}',
#  '; Speak',
#  '$talk     = $answer | $speak',
#  '$answer   = answer a {question}',
#  '$speak    = $vbspeak $whattosay',
#  '##############################################################################',
#  '#',
#  '# What to say',
#  '#',
#  '##############################################################################',
#  '$whattosay = something about yourself',
#  '$whattosay = the time',
#  '$whattosay = what day is (today | tomorrow)',
#  "$whattosay = your team's (name | country | affiliation)",
#  '$whattosay = the day of the (week | month)',
#  '$whattosay = a joke',
#  '##############################################################################',
#  '#',
#  '# Verbs',
#  '#',
#  '##############################################################################',
#  '$vbbtake   = bring | take',
#  '$vbplace   = put | place',
#  '$vbbring   = bring | give',
#  '$vbdeliver = $vbbring | deliver',
#  '$vbtake    = get | grasp | take | pick up',
#  '$vbspeak   = tell | say',
#  '$vbgopl    = go | navigate',
#  '$vbgor     = $vbgopl | enter',
#  '$vbfind    = find | locate | look for',
#  '$vbguide   = guide | escort | take | lead | accompany',
#  '$vbfollow  = follow',
#  '$vbfollow  = (go | come) after',
#  '##############################################################################',
#  '#',
#  '# Polite',
#  '#',
#  '##############################################################################',
#  '$polite   = {void} | Please',
#  '$polite   = Could you',
#  '$polite   = Robot please',
#  '$polite   = Could you please']

# %%
# task
# polite + task
# task + please



dic = {task_type:task}

# %% [markdown]
# # Parameters

# %%
# load parameters from yaml
# ================================================================================================================
# yaml_dict = yaml.load(open('../../../../../ros/config/config_mbot_nlu_training.yaml'))['slots_train']
# random_state = eval(yaml_dict['resample_random_state'])
random_state = 42


# params for balancing individual structures
# ================================================================================================================
# number of types of different structured sentences in each of intent classes
# True/False dictates if the sentences in this intent class will be included in the training data
n_struct = {'go': (45, False), 'take': (52, True), 'find': (44, True), 'answer': (2, False), 'tell': (11, False), 'guide': (18, True), 'follow': (14, True), 'meet': (0, False)}

# number of samples per structe required enough to make balances data
# n_samples_per_intent = int(yaml_dict['n_examples']/len([item for item in n_struct.keys() if n_struct[item][0]!=0 and n_struct[item][1]]))
n_samples_per_intent = int(55000/len([item for item in n_struct.keys() if n_struct[item][0]!=0 and n_struct[item][1]]))


# data slider. bigger the value, bigger the number of sentences with complex structures(eg: grasp to mia at the kitchen the bottle from the bed room)
# but bigger the repeatation of sentences with smaller structure(eg: go to the kitchen)
# control the distribution of simple and complext sentences.

data_slider = 0 #yaml_dict['data_slider']

# %% [markdown]
# # Vocabulary

# %%
# ################################################################################################################
#                                           NOUNS (for sentence generation)                                      #
# ################################################################################################################

# data for creating sentences eg: [names, objects]
# ================================================================================================================
# objects
# ================================================================================================================
objects_a = ['snack -Bobject-', 'cereals -Bobject bar -Iobject-', 'cookie -Bobject-', 'book -Bobject-', 'pen -Bobject-', 'notebook -Bobject-',
            'laptop -Bobject-', 'tablet -Bobject-', 'charger -Bobject-', 'pencil -Bobject-', 'peanut -Bobject-',
            'biscuit -Bobject-', 'candy -Bobject-', 'chocolate -Bobject bar -Iobject-', 'chewing -Bobject- gum -Iobject-',
            'chocolate -Bobject- egg -Iobject-', 'chocolate -Bobject- tablet -Iobject-', 'donuts -Bobject-', 'cake -Bobject-', 'pie -Bobject-',
            'peach -Bobject-', 'strawberry -Bobject-', 'blueberry -Bobject-', 'blackberry -Bobject-', 'burger -Bobject-', 'lemon -Bobject-',
            'banana -Bobject-', 'watermelon -Bobject-', 'pepper -Bobject-', 'pear -Bobject-', 'pizza -Bobject-', 'yogurt -Bobject-',
            'drink -Bobject-', 'beer -Bobject-', 'coke -Bobject-', 'sprite -Bobject-', 'sake -Bobject-', 'toothpaste -Bobject-',
            'cream -Bobject-', 'lotion -Bobject-', 'dryer -Bobject-', 'comb -Bobject-', 'towel -Bobject-', 'shampoo -Bobject-',
            'soap -Bobject-', 'cloth -Bobject-', 'sponge -Bobject-', 'toothbrush -Bobject-', 'container -Bobject-', 'glass -Bobject-',
            'can -Bobject-', 'bottle -Bobject-', 'fork -Bobject-', 'knife -Bobject-', 'bowl -Bobject-', 'tray -Bobject-', 'plate -Bobject-',
            'newspaper -Bobject-', 'magazine -Bobject-', 'kleenex -Bobject-', 'whiteboard -Bobject- cleaner -Iobject-']

objects_an = ['apple -Bobject-', 'almond -Bobject-', 'onion -Bobject-', 'orange -Bobject-']

objects_the = ['cookies -Bobject-', 'almonds -Bobject-', 'book -Bobject-', 'pen -Bobject-', 'notebook -Bobject-', 'laptop -Bobject-',
            'tablet -Bobject-', 'charger -Bobject-', 'pencil -Bobject-', 'chips -Bobject-', 'senbei -Bobject-', 'pringles -Bobject-',
            'peanuts -Bobject-', 'biscuits -Bobject-', 'crackers -Bobject-', 'candies -Bobject-', 'chocolate -Bobject bar -Iobject-',
            'manju -Bobject-', 'mints -Bobject-', 'chewing -Bobject- gums -Iobject-', 'chocolate -Bobject- egg -Iobject-',
            'chocolate -Bobject- tablet -Iobject-', 'donuts -Bobject-', 'cake -Bobject-', 'pie -Bobject-', 'food -Bobject-',
            'peach -Bobject-', 'strawberries -Bobject-', 'grapes -Bobject-', 'blueberries -Bobject-', 'blackberries -Bobject-',
            'salt -Bobject-', 'sugar -Bobject-', 'bread -Bobject-', 'cheese -Bobject-', 'ham -Bobject-', 'burger -Bobject-', 'ham -Bobject- burger -Iobject-',
            'lemon -Bobject-', 'onion -Bobject-', 'lemons -Bobject-', 'apples -Bobject-', 'onions -Bobject-', 'orange -Bobject-', 'oranges -Bobject-',
            'peaches -Bobject-', 'banana -Bobject-', 'bananas -Bobject-', 'noodles -Bobject-', 'apple -Bobject-', 'paprika -Bobject-',
            'watermelon -Bobject-', 'sushi -Bobject-', 'pepper -Bobject-', 'pear -Bobject-', 'pizza -Bobject-', 'yogurt -Bobject-',
            'drink -Bobject-', 'milk -Bobject-', 'juice -Bobject-', 'coffee -Bobject-', 'hot -Bobject- chocolate', 'whisky -Bobject-',
            'rum -Bobject-', 'vodka -Bobject-', 'cider -Bobject-', 'lemonade -Bobject-', 'tea -Bobject-', 'water -Bobject-', 'beer -Bobject-',
            'coke -Bobject-', 'sprite -Bobject-', 'wine -Bobject-', 'sake -Bobject-', 'toiletries -Bobject-', 'toothpaste -Bobject-',
            'cream -Bobject-', 'lotion -Bobject-', 'dryer -Bobject-', 'comb -Bobject-', 'towel -Bobject-', 'shampoo -Bobject-', 'soap -Bobject-',
            'cloth -Bobject-', 'sponge -Bobject-', 'toilet -Bobject- paper -Iobject-', 'toothbrush -Bobject-', 'container -Bobject-', 'containers -Bobject-',
            'glass -Bobject-', 'can -Bobject-', 'bottle -Bobject-', 'fork -Bobject-', 'knife -Bobject-', 'bowl -Bobject-', 'tray -Bobject-',
            'plate -Bobject-', 'newspaper -Bobject-', 'magazine -Bobject-', 'rice -Bobject-','kleenex -Bobject-',
            'whiteboard -Bobject- cleaner -Iobject-', 'cup -Bobject-', 'big -Bobject- dish -Iobject-', 'choco -Bobject- flakes -Iobject-']

objects_some = ['snacks -Bobject-', 'cookies -Bobject-', 'almonds -Bobject-', 'books -Bobject-', 'pens -Bobject-', 'chips -Bobject-',
            'pringles -Bobject-', 'magazines -Bobject-', 'newspapers -Bobject-', 'peanuts -Bobject-', 'biscuits -Bobject-', 'crackers -Bobject-',
            'candies -Bobject-', 'mints -Bobject-', 'chewing -Bobject- gums -Iobject-', 'donuts -Bobject-', 'cake -Bobject-', 'pie -Bobject-',
            'food -Bobject-', 'strawberries -Bobject-', 'grapes -Bobject-', 'blueberries -Bobject-', 'blackberries -Bobject-', 'salt -Bobject-',
            'sugar -Bobject-', 'bread -Bobject-', 'cheese -Bobject-', 'ham -Bobject-', 'lemons -Bobject-', 'apples -Bobject-',
            'onions -Bobject-', 'oranges -Bobject-', 'peaches -Bobject-', 'bananas -Bobject-', 'noodles -Bobject-', 'paprika -Bobject-',
            'watermelon -Bobject-', 'sushi -Bobject-', 'pepper -Bobject-', 'pizza -Bobject-', 'yogurt -Bobject-', 'drink -Bobject-',
            'milk -Bobject-', 'juice -Bobject-', 'coffee -Bobject-', 'hot -Bobject- chocolate -Iobject-',
            'whisky -Bobject-', 'rum -Bobject-', 'vodka -Bobject-', 'cider -Bobject-', 'lemonade -Bobject-', 'tea -Bobject-', 'water -Bobject-',
            'beer -Bobject-', 'coke -Bobject-', 'sprite -Bobject-', 'wine -Bobject-', 'sake -Bobject-', 'toilet -Bobject- paper -Iobject-',
            'containers -Bobject-', 'glasses -Bobject-', 'cans -Bobject-', 'bottles -Bobject-', 'forks -Bobject-', 'knives -Bobject-',
            'bowls -Bobject-', 'trays -Bobject-', 'plates -Bobject-', 'lemon -Bobject-', 'rice -Bobject-', 'cups -Bobject-']

objects_a_piece_of = ['cake -Bobject-', 'pie -Bobject-', 'bread -Bobject-', 'cheese -Bobject-', 'ham -Bobject-', 'watermelon -Bobject-',
                     'sushi -Bobject-', 'pizza -Bobject-', 'apple -Bobject-', 'lemon -Bobject-']

objects_a_cup_of = ['milk -Bobject-', 'coffee -Bobject-', 'hot -Bobject- chocolate -Iobject-', 'cider -Bobject-', 'lemonade -Bobject-',
                    'tea -Bobject-', 'water -Bobject-', 'beer -Bobject-', 'juice -Bobject-', 'rice -Bobject-']

objects_a_can_of = ['red -Bobject balls -Iobject-', 'cider -Bobject-', 'iced -Bobject- tea -Iobject-', 'beer -Bobject-', 'coke -Bobject-',
                     'sprite -Bobject-', 'juice -Bobject-', 'kleenex -Bobject-']

objects_a_glass_of = ['milk -Bobject-', 'juice -Bobject-', 'coffee -Bobject-', 'hot -Bobject- chocolate -Iobject-', 'whisky -Bobject-',
                    'rum -Bobject-', 'vodka -Bobject-', 'cider -Bobject-', 'lemonade -Bobject-', 'iced -Bobject- tea -Iobject-',
                    'water -Bobject-', 'beer -Bobject-', 'coke -Bobject-', 'sprite -Bobject-', 'wine -Bobject-', 'sake -Bobject-']

objects_a_bottle_of = ['milk -Bobject-', 'juice -Bobject-', 'whisky -Bobject-', 'rum -Bobject-', 'vodka -Bobject-', 'cider -Bobject-',
                     'lemonade -Bobject-', 'iced -Bobject- tea -Iobject-', 'water -Bobject-', 'beer -Bobject-', 'coke -Bobject-',
                     'sprite -Bobject-', 'wine -Bobject-','sake -Bobject-', 'kleenex -Bobject-']

objects = list(set(objects_a + objects_the + objects_some + objects_an + objects_a_piece_of + objects_a_cup_of + objects_a_can_of + objects_a_bottle_of + objects_a_glass_of))

del objects_a, objects_some, objects_an, objects_a_piece_of, objects_a_cup_of, objects_a_can_of, objects_a_bottle_of, objects_a_glass_of

# ================================================================================================================
# locations
# ================================================================================================================
locations_on = ['nightstand -Blocation-', 'bookshelf -Blocation-', 'coffee -Blocation- table -Ilocation-', 'side -Blocation- table -Ilocation-',
                'kitchen -Blocation- table -Ilocation-', 'kitchen -Blocation- cabinet -Ilocation-', 'tv -Blocation- stand -Ilocation-',
                'sofa -Blocation-', 'couch -Blocation-', 'bedroom -Blocation- chair -Ilocation-', 'kitchen -Blocation- chair -Ilocation-',
                'living -Blocation- room -Ilocation- table -Ilocation-', 'center -Blocation- table -Ilocation-', 'drawer -Blocation-', 'desk -Blocation-',
                'cupboard -Blocation-', 'side -Blocation- shelf -Ilocation-', 'bookcase -Blocation-', 'dining -Blocation- table -Ilocation-',
                'fridge -Blocation-', 'counter -Blocation-', 'cabinet -Blocation-', 'table -Blocation-', 'bedchamber -Blocation-', 'chair -Blocation-',
                'dryer -Blocation-', 'oven -Blocation-', 'rocking -Blocation- chair -Ilocation-', 'stove -Blocation-', 'television -Blocation-',
                'dressing -Blocation- table -Ilocation-', 'bench -Blocation-', 'futon -Blocation-', 'beanbag -Blocation-', 'stool -Blocation-',
                'sideboard -Blocation-', 'washing -Blocation- machine -Ilocation-', 'dishwasher -Blocation-']

locations_in = ['wardrobe -Blocation-', 'nightstand -Blocation-', 'bookshelf -Blocation-', 'dining -Blocation- room -Ilocation-', 'bedroom -Blocation-',
                'closet -Blocation-', 'living -Blocation- room -Ilocation-', 'bar -Blocation-', 'office -Blocation-', 'drawer -Blocation-',
                'kitchen -Blocation-', 'cupboard -Blocation-', 'side -Blocation- shelf -Ilocation-', 'fridge -Blocation-', 'corridor -Blocation-',
                'cabinet -Blocation-', 'bathroom -Blocation-', 'toilet -Blocation-', 'hall -Blocation-', 'hallway -Blocation-',
                'master -Blocation- bedroom -Ilocation-', 'dormitory -Blocation- room -Ilocation-', 'bedchamber -Blocation-', 'cellar -Blocation-',
                'den -Blocation-', 'garage -Blocation-', 'playroom -Blocation-', 'porch -Blocation-', 'staircase -Blocation-',
                'sun -Blocation- room -Ilocation-', 'music -Blocation- room -Ilocation-', 'prayer -Blocation- room -Ilocation-',
                'utility -Blocation- room -Ilocation-', 'shed -Blocation-', 'basement -Blocation-', 'workshop -Blocation-',
                'ballroom -Blocation-', 'box -Blocation- room -Ilocation-', 'conservatory -Blocation-', 'drawing -Blocation- room -Ilocation-',
                'games -Blocation- room -Ilocation-', 'larder -Blocation-', 'library -Blocation-', 'parlour -Blocation-', 'guestroom -Blocation-',
                'crib -Blocation-', 'shower -Blocation-']

locations_at = ['wardrobe -Blocation-', 'nightstand -Blocation-', 'bookshelf -Blocation-', 'coffee -Blocation- table -Ilocation-',
                'side -Blocation- table -Ilocation-', 'kitchen -Blocation- table -Ilocation-', 'kitchen -Blocation- cabinet -Ilocation-',
                'bed -Blocation-', 'bedside -Blocation-', 'closet -Blocation-', 'tv -Blocation- stand -Ilocation-', 'sofa -Blocation-',
                'couch -Blocation-', 'bedroom -Blocation- chair -Ilocation-', 'kitchen -Blocation- chair -Ilocation-',
                'living -Blocation- room -Ilocation- table -Ilocation-', 'center -Blocation- table -Ilocation-', 'bar -Blocation-',
                'drawer -Blocation-', 'desk -Blocation-', 'cupboard -Blocation-', 'sink -Blocation-', 'side -Blocation- shelf -Ilocation-',
                'bookcase -Blocation-', 'dining -Blocation- table -Ilocation-', 'fridge -Blocation-', 'counter -Blocation-', 'door -Blocation-',
                'cabinet -Blocation-', 'table -Blocation-', 'master -Blocation- bedroom -Ilocation-', 'dormitory -Blocation- room -Ilocation-',
                'bedchamber -Blocation-', 'chair -Blocation-', 'dryer -Blocation-', 'entrance -Blocation-', 'garden -Blocation-',
                'oven -Blocation-', 'rocking -Blocation- chair -Ilocation-', 'room -Blocation-', 'stove -Blocation-', 'television -Blocation-',
                'washer -Blocation-', 'cellar -Blocation-', 'den -Blocation-', 'laundry -Blocation-', 'pantry -Blocation-', 'patio -Blocation-',
                'balcony -Blocation-', 'lamp -Blocation-', 'window -Blocation-', 'lawn -Blocation-', 'cloakroom -Blocation-', 'telephone -Blocation-',
                'dressing -Blocation- table -Ilocation-', 'bench -Blocation-', 'futon -Blocation-', 'radiator -Blocation-',
                'washing -Blocation- machine -Ilocation-', 'dishwasher -Blocation-']

locations = list(set(locations_at+locations_in+locations_on))


# ================================================================================================================
# names
# ================================================================================================================
names_female = ['hanna -Bperson-', 'barbara -Bperson-', 'samantha -Bperson-', 'erika -Bperson-', 'sophie -Bperson-', 'jackie -Bperson-',
                'skyler -Bperson-', 'jane -Bperson-', 'olivia -Bperson-', 'emily -Bperson-', 'amelia -Bperson-', 'lily -Bperson-',
                'grace -Bperson-', 'ella -Bperson-', 'scarlett -Bperson-', 'isabelle -Bperson-', 'charlotte -Bperson-', 'daisy -Bperson-',
                'sienna -Bperson-', 'chloe -Bperson-', 'alice -Bperson-', 'lucy -Bperson-', 'florence -Bperson-', 'rosie -Bperson-',
                'amelie -Bperson-', 'eleanor -Bperson-', 'emilia -Bperson-', 'amber -Bperson-', 'ivy -Bperson-', 'brooke -Bperson-',
                'summer -Bperson-', 'emma -Bperson-', 'rose -Bperson-', 'martha -Bperson-', 'faith -Bperson-', 'amy -Bperson-',
                'mia -Bperson-', 'sophia -Bperson-', 'abigail -Bperson-', 'isabella -Bperson-', 'ava -Bperson-',
                'katie -Bperson-', 'madison -Bperson-', 'sarah -Bperson-', 'zoe -Bperson-', 'paige -Bperson-']

names_male = ['ken -Bperson-', 'erik -Bperson-', 'samuel -Bperson-', 'skyler -Bperson-', 'brian -Bperson-', 'thomas -Bperson-',
            'edward -Bperson-', 'michael -Bperson-', 'charlie -Bperson-', 'alex -Bperson-', 'john -Bperson-', 'james -Bperson-',
            'oscar -Bperson-', 'peter -Bperson-', 'oliver -Bperson-', 'jack -Bperson-', 'harry -Bperson-', 'henry -Bperson-',
            'jacob -Bperson-', 'thomas -Bperson-', 'william -Bperson-', 'will -Bperson-', 'joshua -Bperson-', 'josh -Bperson-',
            'noah -Bperson-', 'ethan -Bperson-', 'joseph -Bperson-', 'samuel -Bperson-', 'daniel -Bperson-', 'max -Bperson-',
            'logan -Bperson-', 'isaac -Bperson-', 'dylan -Bperson-', 'freddie -Bperson-', 'tyler -Bperson-', 'harrison -Bperson-',
            'adam -Bperson-', 'theo -Bperson-', 'arthur -Bperson-', 'toby -Bperson-', 'luke -Bperson-', 'lewis -Bperson-',
            'matthew -Bperson-', 'harvey -Bperson-', 'ryan -Bperson-', 'tommy -Bperson-', 'michael -Bperson-', 'nathan -Bperson-',
            'blake -Bperson-', 'charles -Bperson-', 'connor -Bperson-', 'jamie -Bperson-', 'elliot -Bperson-', 'louis -Bperson-',
            'liam -Bperson-', 'mason -Bperson-', 'alexander -Bperson-', 'madison -Bperson-',
            'aaron -Bperson-', 'evan -Bperson-', 'seth -Bperson-']

names = list(set(names_male+names_female))
del names_male, names_female

# ================================================================================================================
# what to tell
# ================================================================================================================
what_to_tell_about = ['name -Bwhat_to_tell-', 'nationality -Bwhat_to_tell-', 'eye -Bwhat_to_tell- color -Iwhat_to_tell-',
                    'hair -Bwhat_to_tell- color -Iwhat_to_tell-','surname -Bwhat_to_tell-', 'middle -Bwhat_to_tell- name -Iwhat_to_tell-', 'gender -Bwhat_to_tell-', 'pose -Bwhat_to_tell-',
                    'age -Bwhat_to_tell-', 'job -Bwhat_to_tell-', 'shirt -Bwhat_to_tell- color -Iwhat_to_tell-',
                    'height -Bwhat_to_tell-', 'mood -Bwhat_to_tell-']

what_to_tell_to = [ "your -Bwhat_to_tell- teams -Iwhat_to_tell- affiliation -Iwhat_to_tell-",
                    "your -Bwhat_to_tell- teams -Iwhat_to_tell- name -Iwhat_to_tell-",
                    'the -Bwhat_to_tell- day -Iwhat_to_tell- of -Iwhat_to_tell- the -Iwhat_to_tell- month -Iwhat_to_tell-',
                    'what -Bwhat_to_tell- day -Iwhat_to_tell- is -Iwhat_to_tell- tomorrow -Iwhat_to_tell-',
                    'the -Bwhat_to_tell- time -Iwhat_to_tell-',
                    'the -Bwhat_to_tell- weather -Iwhat_to_tell-',
                    'that -Bwhat_to_tell- i -Iwhat_to_tell- am -Iwhat_to_tell- coming -Iwhat_to_tell-',
                    'to -Bwhat_to_tell- wait -Iwhat_to_tell- a -Iwhat_to_tell- moment -Iwhat_to_tell-',
                    'to -Bwhat_to_tell- come -Iwhat_to_tell- here -Iwhat_to_tell-',
                    'what -Bwhat_to_tell- time -Iwhat_to_tell- is -Iwhat_to_tell- it -Iwhat_to_tell-',
                    'a -Bwhat_to_tell- joke -Iwhat_to_tell-',
                    'something -Bwhat_to_tell- about -Iwhat_to_tell- yourself -Iwhat_to_tell-',
                    'the -Bwhat_to_tell- name -Iwhat_to_tell- of -Iwhat_to_tell- the -Iwhat_to_tell- person -Iwhat_to_tell-']

# ================================================================================================================
# introductions
# ================================================================================================================
intros = ['robot', 'hello robot', 'hello', 'please', 'could you please', 'robot please', 'can you', 'robot can you', 'robot could you', 'could you']


# ################################################################################################################
#                                                  USER FEEDBACK                                                 #
# ################################################################################################################

# printing number of objects used in the generator
print('objects', len(objects))
print('locations', len(sorted(locations, key=str.lower)))
print('names', len(names))
print('what_to_tell_to', len(what_to_tell_to))
print('intros', len(intros))
print('-----------------------------------------------------')

# initiating lists (2 per intent)
tasks_take = []; tasks_take_ = []
tasks_follow = []; tasks_follow_ =[]
tasks_answer = []; tasks_answer_ = []
tasks_find = []; tasks_find_ = []
tasks_guide = []; tasks_guide_ = []
tasks_tell = []; tasks_tell_ = []
tasks_go = []; tasks_go_ = []
tasks_meet = []; tasks_meet_ = []
# Out:
# objects 133
# locations 95
# names 102
# what_to_tell_to 13
# intros 10
# -----------------------------------------------------

# %% [markdown]
# # Sentence Structure Definitions

# %%
# ################################################################################################################
#                                         SENTENCE STRUCTURE DEFINISTIONS                                        #
# ################################################################################################################

#------------------------------------------GO----------------------------------------------
if n_struct['go'][1]:

    tasks_go_.append(['go to ' + name for name in names])
    tasks_go_.append(['navigate to ' + name for name in names])
    tasks_go_.append(['proceed to ' + name for name in names])
    tasks_go_.append(['move to ' + name for name in names])
    tasks_go_.append(['advance to ' + name for name in names])
    tasks_go_.append(['travel to ' + name for name in names])
    tasks_go_.append(['drive to ' + name for name in names])
    tasks_go_.append(['come to ' + name for name in names])
    tasks_go_.append(['go near to ' + name for name in names])
    tasks_go_.append(['walk to ' + name for name in names])
    tasks_go_.append(['reach ' + name for name in names])

    tasks_go_.append(['go to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['navigate to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['proceed to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['move to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['advance to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['travel to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['drive to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['come to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['go near the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['walk to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['reach the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['enter the ' + location.replace('location', 'destination') for location in locations])

    tasks_go_.append(['go to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['navigate to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['proceed to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['move to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['advance to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['travel to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['drive to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['come to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['go near ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['walk to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['reach ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])

    tasks_go_.append(['go to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['navigate to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['proceed to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['move to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['advance to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['travel to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['drive to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['come to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['go near ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['walk to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['reach ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])

    # resampling and appending individual structures
    len_of_str = [len(tasks_go_[i]) for i in range(len(tasks_go_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_go_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_go_[i] = resample(tasks_go_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_go_[i] = resample(tasks_go_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_go = [item for sublist in tasks_go_ for item in sublist]
    # rem temp params
    del tasks_go_, len_of_str, mean_of_strct_lens
    print ("number of 'go' sentences", len(tasks_go))

#----------------------------------------TAKE---------------------------------------------
if n_struct['take'][1]:

    tasks_take_.append(['grasp the ' + objet for objet in objects])
    tasks_take_.append(['pick up the ' + objet for objet in objects])

    tasks_take_.append(['bring me -Bperson- the ' + objet for objet in objects])
    tasks_take_.append(['give me -Bperson- the ' + objet for objet in objects])

    tasks_take_.append(['take the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['put the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['deliver the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['take the ' + objet + ' to ' + name for objet in objects for name in names])
    tasks_take_.append(['deliver the ' + objet + ' to ' + name for objet in objects for name in names])
    tasks_take_.append(['give the ' + objet + ' to ' + name for objet in objects for name in names])

    # ADDED SENTENCES FROM GPSR COMMAND GEN FOR ROBOCUP 2018
    # ===========================================================================================
    tasks_take_.append(['grasp the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects for location in locations])
    tasks_take_.append(['pick up the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects for location in locations])

    tasks_take_.append(['bring the ' + objet + ' to ' + name for objet in objects_the for name in names])

    tasks_take_.append(['bring me -Bperson- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])
    tasks_take_.append(['give me -Bperson- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])

    tasks_take_.append(['bring the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations])

    tasks_take_.append(['bring the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['deliver the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['give the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['hand the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['hand over the ' + objet + ' to me -Bperson-' for objet in objects_the])

    tasks_take_.append(['deliver the ' + objet + ' to ' + name for objet in objects_the for name in names])
    tasks_take_.append(['deliver the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])
    tasks_take_.append(['give the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])
    tasks_take_.append(['hand the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])
    tasks_take_.append(['hand over the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])

    tasks_take_.append(['bring to ' + name + ' at the ' + location.replace('location', 'destination') + ' the ' + objet + ' from the ' + location2.replace('location', 'source') for name in names for location in locations_at[:int(len(locations_at)/2)] for objet in objects_the for location2 in locations[:int(len(locations)/8)] if location!=location2])
    tasks_take_.append(['give to ' + name + ' at the ' + location.replace('location', 'destination') + ' the ' + objet + ' from the ' + location2.replace('location', 'source') for name in names for location in locations_at[:int(len(locations_at)/2)] for objet in objects_the for location2 in locations[:int(len(locations)/8)] if location!=location2])

    tasks_take_.append(['get the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])
    tasks_take_.append(['get the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects_the for location in locations])
    tasks_take_.append(['take the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])
    tasks_take_.append(['retrieve the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])

    tasks_take_.append(['get the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects_the for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])
    tasks_take_.append(['take the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects_the for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])

    tasks_take_.append(['place the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['place ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['put the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['put ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['set the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['set ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['leave the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects for location in locations_on])
    tasks_take_.append(['leave ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects for location in locations_on])

    # CHANGED FROM GRASP TO TAKE ACCORDING TO MITHUN
    # ===========================================================================================
    tasks_take_.append(['grasp the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['pick up the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])

    tasks_take_.append(['grasp the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])
    tasks_take_.append(['pick up the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])


    # resampling and appending individual structures
    len_of_str = [len(tasks_take_[i]) for i in range(len(tasks_take_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_take_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_take_[i] = resample(tasks_take_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_take_[i] = resample(tasks_take_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_take = [item for sublist in tasks_take_ for item in sublist]
    # rem temp params
    del tasks_take_, len_of_str, mean_of_strct_lens
    print ("number of 'take' sentences", len(tasks_take))

#-----------------------------------------------FIND-----------------------------------------------
if n_struct['find'][1]:

    tasks_find_.append(['find the ' + objet for objet in objects])
    tasks_find_.append(['look for the ' + objet for objet in objects])
    tasks_find_.append(['locate the ' + objet for objet in objects])
    tasks_find_.append(['pinpoint the ' + objet for objet in objects])
    tasks_find_.append(['spot the ' + objet for objet in objects])
    tasks_find_.append(['search for the ' + objet for objet in objects])

    tasks_find_.append(['find the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['look for the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['locate the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['pinpoint the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['spot the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['search for the ' + objet + ' in the ' + location for objet in objects for location in locations_in])

    tasks_find_.append(['find ' + name for name in names])
    tasks_find_.append(['look for ' + name for name in names])
    tasks_find_.append(['locate ' + name for name in names])
    tasks_find_.append(['pinpoint ' + name for name in names])
    tasks_find_.append(['spot ' + name for name in names])
    tasks_find_.append(['search for ' + name for name in names])

    tasks_find_.append(['find ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['look for ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['locate ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['pinpoint ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['spot ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['search for ' + name + ' in the ' + location for name in names for location in locations_in])

    tasks_find_.append(['find ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['look for ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['locate ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['pinpoint ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['spot ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['search for ' + name + ' at the ' + location for name in names for location in locations_at])
    # ADDED SENTENCES FROM GPSR COMMAND GEN FOR ROBOCUP 2018
    # ===========================================================================================
    tasks_find_.append(['find someone -Bperson-'])
    tasks_find_.append(['locate someone -Bperson-'])
    tasks_find_.append(['look for someone -Bperson-'])
    tasks_find_.append(['find a person -Bperson-'])
    tasks_find_.append(['locate a person -Bperson-'])
    tasks_find_.append(['look for a person -Bperson-'])
    tasks_find_.append(['search for a person - find'])

    tasks_find_.append(['find a person -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['locate a person -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['look for a person -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['find someone -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['look for someone -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['locate someone -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['search for someone' + ' in the ' + location for location in locations_in])


    # resampling and appending individual structures
    len_of_str = [len(tasks_find_[i]) for i in range(len(tasks_find_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_find_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_find_[i] = resample(tasks_find_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_find_[i] = resample(tasks_find_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_find = [item for sublist in tasks_find_ for item in sublist]
    # rem temp params
    del tasks_find_, len_of_str, mean_of_strct_lens
    print ("number of 'find' sentences", len(tasks_find))

#--------------------------------------------ANSWER-------------------------------------
if n_struct['answer'][1]:

    tasks_answer_.append(['answer a question to ' + name for name in names])
    tasks_answer_.append(['answer a question to ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations])

    # resampling and appending individual structures
    len_of_str = [len(tasks_answer_[i]) for i in range(len(tasks_answer_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_answer_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_answer_[i] = resample(tasks_answer_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_answer_[i] = resample(tasks_answer_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_answer = [item for sublist in tasks_answer_ for item in sublist]
    # rem temp params
    del tasks_answer_, len_of_str, mean_of_strct_lens
    print ("number of 'answer' sentences", len(tasks_answer))

#---------------------------------------------TELL-------------------------------------
if n_struct['tell'][1]:

    tasks_tell_.append(['tell ' + w + ' to ' + name for w in what_to_tell_to for name in names])
    tasks_tell_.append(['say ' + w + ' to ' + name for w in what_to_tell_to for name in names])
    tasks_tell_.append(['tell ' + w + ' to ' + name + ' at the ' + location.replace('location', 'destination') for w in what_to_tell_to for name in names for location in locations])
    tasks_tell_.append(['say ' + w + ' to ' + name + ' at the ' + location.replace('location', 'destination') for w in what_to_tell_to for name in names for location in locations])

    # ADDED SENTENCES FROM GPSR COMMAND GEN FOR ROBOCUP 2018
    # ===========================================================================================
    tasks_tell_.append(['say ' + w for w in what_to_tell_to])
    tasks_tell_.append(['tell ' + w for w in what_to_tell_to])
    tasks_tell_.append(['tell me -Bperson- ' + w for w in what_to_tell_to])

    tasks_tell_.append(['tell me -Bperson- the name -Bwhat_to_tell- of -Iwhat_to_tell- the -Iwhat_to_tell- person -Iwhat_to_tell- at the ' + location.replace('location', 'destination') for location in locations_at])
    tasks_tell_.append(['tell me -Bperson- the name -Bwhat_to_tell- of -Iwhat_to_tell- the -Iwhat_to_tell- person -Iwhat_to_tell- in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_tell_.append(['tell me -Bperson- how -Bwhat_to_tell- many -Iwhat_to_tell- ' + objet + ' there are on the ' + location.replace('location', 'destination') for objet in objects for location in locations_on])
    # added extra for test
    tasks_tell_.append(['tell to '+ name + ' how -Bwhat_to_tell- many -Iwhat_to_tell- ' + objet + ' there are on the ' + location.replace('location', 'destination') for name in names for objet in objects for location in locations_on])
    # resampling and appending individual structures
    len_of_str = [len(tasks_tell_[i]) for i in range(len(tasks_tell_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_tell_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_tell_[i] = resample(tasks_tell_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_tell_[i] = resample(tasks_tell_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_tell = [item for sublist in tasks_tell_ for item in sublist]
    # rem temp params
    del tasks_tell_, len_of_str, mean_of_strct_lens
    print ("number of 'tell' sentences", len(tasks_tell))

#---------------------------------------------GUIDE-------------------------------------
if n_struct['guide'][1]:

    tasks_guide_.append(['accompany ' + name for name in names])
    tasks_guide_.append(['conduct ' + name for name in names])
    tasks_guide_.append(['escort ' + name for name in names])
    tasks_guide_.append(['guide ' + name for name in names])
    tasks_guide_.append(['lead ' + name for name in names])
    tasks_guide_.append(['take ' + name for name in names])
    tasks_guide_.append(['oversee ' + name for name in names])
    tasks_guide_.append(['supervise ' + name for name in names])
    tasks_guide_.append(['usher ' + name for name in names])

    tasks_guide_.append(['accompany ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['conduct ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['escort ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['guide ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['lead ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['take ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['oversee ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['supervise ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['usher ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])

    # resampling and appending individual structures
    len_of_str = [len(tasks_guide_[i]) for i in range(len(tasks_guide_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_guide_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_guide_[i] = resample(tasks_guide_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_guide_[i] = resample(tasks_guide_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_guide = [item for sublist in tasks_guide_ for item in sublist]
    # rem temp params
    del tasks_guide_, len_of_str, mean_of_strct_lens
    print ("number of 'guide' sentences", len(tasks_guide))

#---------------------------------------------FOLLOW-------------------------------------
if n_struct['follow'][1]:

    tasks_follow_.append(['come after ' + name for name in names])
    tasks_follow_.append(['go after ' + name for name in names])
    tasks_follow_.append(['come behind ' + name for name in names])
    tasks_follow_.append(['go behind ' + name for name in names])
    tasks_follow_.append(['follow ' + name for name in names])
    tasks_follow_.append(['pursue ' + name for name in names])
    tasks_follow_.append(['chase ' + name for name in names])

    tasks_follow_.append(['come after '  + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['go after ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['come behind ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['go behind ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['follow ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['pursue ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['chase ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])

    # resampling and appending individual structures
    len_of_str = [len(tasks_follow_[i]) for i in range(len(tasks_follow_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_follow_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_follow_[i] = resample(tasks_follow_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_follow_[i] = resample(tasks_follow_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_follow = [item for sublist in tasks_follow_ for item in sublist]
    # rem temp params
    del tasks_follow_, len_of_str, mean_of_strct_lens
    print ("number of 'follow' sentences", len(tasks_follow))

print('-----------------------------------------------------')
#----------------------------------------------------------------------------------------------
# Out:
# number of 'take' sentences 10868604
# number of 'find' sentences 104720
# number of 'guide' sentences 88128
# number of 'follow' sentences 68544
# -----------------------------------------------------

# %% [markdown]
# # Try

# %% [markdown]
#  -Bgo-, -Btake_

# %%
if n_struct['go'][1]:

    tasks_go_.append(['go -Bgo- to ' + name for name in names])
    tasks_go_.append(['navigate -Bgo- to ' + name for name in names])
    tasks_go_.append(['proceed -Bgo- to ' + name for name in names])
    tasks_go_.append(['move -Bgo- to ' + name for name in names])
    tasks_go_.append(['advance -Bgo- to ' + name for name in names])
    tasks_go_.append(['travel -Bgo- to ' + name for name in names])
    tasks_go_.append(['drive -Bgo- to ' + name for name in names])
    tasks_go_.append(['come -Bgo- to ' + name for name in names])
    tasks_go_.append(['go -Bgo- near to ' + name for name in names])
    tasks_go_.append(['walk -Bgo- to ' + name for name in names])
    tasks_go_.append(['reach -Bgo- ' + name for name in names])

    tasks_go_.append(['go -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['navigate -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['proceed -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['move -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['advance -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['travel -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['drive -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['come -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['go -Bgo- near the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['walk -Bgo- to the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['reach -Bgo- the ' + location.replace('location', 'destination') for location in locations])
    tasks_go_.append(['enter -Bgo- the ' + location.replace('location', 'destination') for location in locations])

    tasks_go_.append(['go -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['navigate -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['proceed -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['move -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['advance -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['travel -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['drive -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['come -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['go -Bgo- near ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['walk -Bgo- to ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])
    tasks_go_.append(['reach -Bgo- ' + name + ' at the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_at])

    tasks_go_.append(['go -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['navigate -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['proceed -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['move -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['advance -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['travel -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['drive -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['come -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['go -Bgo- near ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['walk -Bgo- to ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])
    tasks_go_.append(['reach -Bgo- ' + name + ' in the ' + location.replace('location', 'destination') + ' - go' for name in names for location in locations_in])

    # resampling and appending individual structures
    len_of_str = [len(tasks_go_[i]) for i in range(len(tasks_go_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_go_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_go_[i] = resample(tasks_go_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_go_[i] = resample(tasks_go_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_go = [item for sublist in tasks_go_ for item in sublist]
    # rem temp params
    del tasks_go_, len_of_str, mean_of_strct_lens
    print ("number of 'go' sentences", len(tasks_go))

#----------------------------------------TAKE---------------------------------------------
if n_struct['take'][1]:

    tasks_take_.append(['grasp -Btake- the ' + objet for objet in objects])
    tasks_take_.append(['pick -Btake- up the ' + objet for objet in objects])

    tasks_take_.append(['bring -Btake- me -Bperson- the ' + objet for objet in objects])
    tasks_take_.append(['give -Btake- me -Bperson- the ' + objet for objet in objects])

    tasks_take_.append(['take -Btake- the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['put -Btake- the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['deliver -Btake- the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['take -Btake- the ' + objet + ' to ' + name for objet in objects for name in names])
    tasks_take_.append(['deliver -Btake- the ' + objet + ' to ' + name for objet in objects for name in names])
    tasks_take_.append(['give -Btake- the ' + objet + ' to ' + name for objet in objects for name in names])

    # ADDED SENTENCES FROM GPSR COMMAND GEN FOR ROBOCUP 2018
    # ===========================================================================================
    tasks_take_.append(['grasp -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects for location in locations])
    tasks_take_.append(['pick -Btake- up the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects for location in locations])

    tasks_take_.append(['bring -Btake- the ' + objet + ' to ' + name for objet in objects_the for name in names])

    tasks_take_.append(['bring -Btake- me -Bperson- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])
    tasks_take_.append(['give -Btake- me -Bperson- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])

    tasks_take_.append(['bring -Btake- the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations])

    tasks_take_.append(['bring -Btake- the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['deliver -Btake- the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['give -Btake- the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['hand -Btake- the ' + objet + ' to me -Bperson-' for objet in objects_the])
    tasks_take_.append(['hand -Btake- over the ' + objet + ' to me -Bperson-' for objet in objects_the])

    tasks_take_.append(['deliver -Btake- the ' + objet + ' to ' + name for objet in objects_the for name in names])
    tasks_take_.append(['deliver -Btake- the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])
    tasks_take_.append(['give -Btake- the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])
    tasks_take_.append(['hand -Btake- the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])
    tasks_take_.append(['hand -Btake- over the ' + objet + ' to ' + name + ' at the ' + location.replace('location', 'destination') for objet in objects_the for name in names for location in locations_at])

    tasks_take_.append(['bring -Btake- to ' + name + ' at the ' + location.replace('location', 'destination') + ' the ' + objet + ' from the ' + location2.replace('location', 'source') for name in names for location in locations_at[:int(len(locations_at)/2)] for objet in objects_the for location2 in locations[:int(len(locations)/8)] if location!=location2])
    tasks_take_.append(['give -Btake- to ' + name + ' at the ' + location.replace('location', 'destination') + ' the ' + objet + ' from the ' + location2.replace('location', 'source') for name in names for location in locations_at[:int(len(locations_at)/2)] for objet in objects_the for location2 in locations[:int(len(locations)/8)] if location!=location2])

    tasks_take_.append(['get -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])
    tasks_take_.append(['get -Btake- the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects_the for location in locations])
    tasks_take_.append(['take -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])
    tasks_take_.append(['retrieve -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') for objet in objects_the for location in locations])

    tasks_take_.append(['get -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects_the for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])
    tasks_take_.append(['take -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects_the for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])

    tasks_take_.append(['place -Btake- the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['place -Btake- ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['put -Btake- the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['put -Btake- ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['set -Btake- the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['set -Btake- ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects_the for location in locations_on])
    tasks_take_.append(['leave -Btake- the ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects for location in locations_on])
    tasks_take_.append(['leave -Btake- ' + objet + ' on the ' + location.replace('location', 'destination') for objet in objects for location in locations_on])

    # CHANGED FROM GRASP TO TAKE ACCORDING TO MITHUN
    # ===========================================================================================
    tasks_take_.append(['grasp -Btake- the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])
    tasks_take_.append(['pick -Btake- up the ' + objet + ' to the ' + location.replace('location', 'destination') for objet in objects for location in locations])

    tasks_take_.append(['grasp -Btake- the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])
    tasks_take_.append(['pick -Btake- up the ' + objet + ' from the ' + location.replace('location', 'source') + ' to the ' + location2.replace('location', 'destination') for objet in objects for location in locations[:int(len(locations)/8)] for location2 in locations[:int(len(locations)/8)] if location!=location2])


    # resampling and appending individual structures
    len_of_str = [len(tasks_take_[i]) for i in range(len(tasks_take_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_take_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_take_[i] = resample(tasks_take_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_take_[i] = resample(tasks_take_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_take = [item for sublist in tasks_take_ for item in sublist]
    # rem temp params
    del tasks_take_, len_of_str, mean_of_strct_lens
    print ("number of 'take' sentences", len(tasks_take))

#-----------------------------------------------FIND-----------------------------------------------
if n_struct['find'][1]:

    tasks_find_.append(['find -Bfind- the ' + objet for objet in objects])
    tasks_find_.append(['look -Bfind- for the ' + objet for objet in objects])
    tasks_find_.append(['locate -Bfind- the ' + objet for objet in objects])
    tasks_find_.append(['pinpoint -Bfind- the ' + objet for objet in objects])
    tasks_find_.append(['spot -Bfind- the ' + objet for objet in objects])
    tasks_find_.append(['search -Bfind- for the ' + objet for objet in objects])

    tasks_find_.append(['find -Bfind- the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['look -Bfind- for the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['locate -Bfind- the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['pinpoint -Bfind- the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['spot -Bfind- the ' + objet + ' in the ' + location.replace('location', 'destination') for objet in objects for location in locations_in])
    tasks_find_.append(['search -Bfind- for the ' + objet + ' in the ' + location for objet in objects for location in locations_in])

    tasks_find_.append(['find -Bfind- ' + name for name in names])
    tasks_find_.append(['look -Bfind- for ' + name for name in names])
    tasks_find_.append(['locate -Bfind- ' + name for name in names])
    tasks_find_.append(['pinpoint -Bfind- ' + name for name in names])
    tasks_find_.append(['spot -Bfind- ' + name for name in names])
    tasks_find_.append(['search -Bfind- for ' + name for name in names])

    tasks_find_.append(['find -Bfind- ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['look for ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['locate ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['pinpoint ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['spot ' + name + ' in the ' + location.replace('location', 'destination') for name in names for location in locations_in])
    tasks_find_.append(['search for ' + name + ' in the ' + location for name in names for location in locations_in])

    tasks_find_.append(['find ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['look for ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['locate ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['pinpoint ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['spot ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations_at])
    tasks_find_.append(['search for ' + name + ' at the ' + location for name in names for location in locations_at])
    # ADDED SENTENCES FROM GPSR COMMAND GEN FOR ROBOCUP 2018
    # ===========================================================================================
    tasks_find_.append(['find someone -Bperson-'])
    tasks_find_.append(['locate someone -Bperson-'])
    tasks_find_.append(['look for someone -Bperson-'])
    tasks_find_.append(['find a person -Bperson-'])
    tasks_find_.append(['locate a person -Bperson-'])
    tasks_find_.append(['look for a person -Bperson-'])
    tasks_find_.append(['search for a person - find'])

    tasks_find_.append(['find a person -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['locate a person -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['look for a person -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['find someone -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['look for someone -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['locate someone -Bperson-' + ' in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_find_.append(['search for someone' + ' in the ' + location for location in locations_in])


    # resampling and appending individual structures
    len_of_str = [len(tasks_find_[i]) for i in range(len(tasks_find_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_find_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_find_[i] = resample(tasks_find_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_find_[i] = resample(tasks_find_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_find = [item for sublist in tasks_find_ for item in sublist]
    # rem temp params
    del tasks_find_, len_of_str, mean_of_strct_lens
    print ("number of 'find' sentences", len(tasks_find))

#--------------------------------------------ANSWER-------------------------------------
if n_struct['answer'][1]:

    tasks_answer_.append(['answer a question to ' + name for name in names])
    tasks_answer_.append(['answer a question to ' + name + ' at the ' + location.replace('location', 'destination') for name in names for location in locations])

    # resampling and appending individual structures
    len_of_str = [len(tasks_answer_[i]) for i in range(len(tasks_answer_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_answer_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_answer_[i] = resample(tasks_answer_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_answer_[i] = resample(tasks_answer_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_answer = [item for sublist in tasks_answer_ for item in sublist]
    # rem temp params
    del tasks_answer_, len_of_str, mean_of_strct_lens
    print ("number of 'answer' sentences", len(tasks_answer))

#---------------------------------------------TELL-------------------------------------
if n_struct['tell'][1]:

    tasks_tell_.append(['tell ' + w + ' to ' + name for w in what_to_tell_to for name in names])
    tasks_tell_.append(['say ' + w + ' to ' + name for w in what_to_tell_to for name in names])
    tasks_tell_.append(['tell ' + w + ' to ' + name + ' at the ' + location.replace('location', 'destination') for w in what_to_tell_to for name in names for location in locations])
    tasks_tell_.append(['say ' + w + ' to ' + name + ' at the ' + location.replace('location', 'destination') for w in what_to_tell_to for name in names for location in locations])

    # ADDED SENTENCES FROM GPSR COMMAND GEN FOR ROBOCUP 2018
    # ===========================================================================================
    tasks_tell_.append(['say ' + w for w in what_to_tell_to])
    tasks_tell_.append(['tell ' + w for w in what_to_tell_to])
    tasks_tell_.append(['tell me -Bperson- ' + w for w in what_to_tell_to])

    tasks_tell_.append(['tell me -Bperson- the name -Bwhat_to_tell- of -Iwhat_to_tell- the -Iwhat_to_tell- person -Iwhat_to_tell- at the ' + location.replace('location', 'destination') for location in locations_at])
    tasks_tell_.append(['tell me -Bperson- the name -Bwhat_to_tell- of -Iwhat_to_tell- the -Iwhat_to_tell- person -Iwhat_to_tell- in the ' + location.replace('location', 'destination') for location in locations_in])
    tasks_tell_.append(['tell me -Bperson- how -Bwhat_to_tell- many -Iwhat_to_tell- ' + objet + ' there are on the ' + location.replace('location', 'destination') for objet in objects for location in locations_on])
    # added extra for test
    tasks_tell_.append(['tell to '+ name + ' how -Bwhat_to_tell- many -Iwhat_to_tell- ' + objet + ' there are on the ' + location.replace('location', 'destination') for name in names for objet in objects for location in locations_on])
    # resampling and appending individual structures
    len_of_str = [len(tasks_tell_[i]) for i in range(len(tasks_tell_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_tell_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_tell_[i] = resample(tasks_tell_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_tell_[i] = resample(tasks_tell_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_tell = [item for sublist in tasks_tell_ for item in sublist]
    # rem temp params
    del tasks_tell_, len_of_str, mean_of_strct_lens
    print ("number of 'tell' sentences", len(tasks_tell))

#---------------------------------------------GUIDE-------------------------------------
if n_struct['guide'][1]:

    tasks_guide_.append(['accompany ' + name for name in names])
    tasks_guide_.append(['conduct ' + name for name in names])
    tasks_guide_.append(['escort ' + name for name in names])
    tasks_guide_.append(['guide ' + name for name in names])
    tasks_guide_.append(['lead ' + name for name in names])
    tasks_guide_.append(['take ' + name for name in names])
    tasks_guide_.append(['oversee ' + name for name in names])
    tasks_guide_.append(['supervise ' + name for name in names])
    tasks_guide_.append(['usher ' + name for name in names])

    tasks_guide_.append(['accompany ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['conduct ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['escort ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['guide ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['lead ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['take ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['oversee ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['supervise ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_guide_.append(['usher ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])

    # resampling and appending individual structures
    len_of_str = [len(tasks_guide_[i]) for i in range(len(tasks_guide_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_guide_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_guide_[i] = resample(tasks_guide_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_guide_[i] = resample(tasks_guide_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_guide = [item for sublist in tasks_guide_ for item in sublist]
    # rem temp params
    del tasks_guide_, len_of_str, mean_of_strct_lens
    print ("number of 'guide' sentences", len(tasks_guide))

#---------------------------------------------FOLLOW-------------------------------------
if n_struct['follow'][1]:

    tasks_follow_.append(['come after ' + name for name in names])
    tasks_follow_.append(['go after ' + name for name in names])
    tasks_follow_.append(['come behind ' + name for name in names])
    tasks_follow_.append(['go behind ' + name for name in names])
    tasks_follow_.append(['follow ' + name for name in names])
    tasks_follow_.append(['pursue ' + name for name in names])
    tasks_follow_.append(['chase ' + name for name in names])

    tasks_follow_.append(['come after '  + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['go after ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['come behind ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['go behind ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['follow ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['pursue ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])
    tasks_follow_.append(['chase ' + name + ' to the ' + location.replace('location', 'destination') for name in names for location in locations])

    # resampling and appending individual structures
    len_of_str = [len(tasks_follow_[i]) for i in range(len(tasks_follow_))]
    mean_of_strct_lens = int(np.mean(len_of_str)) + data_slider
    for i in range(len(tasks_follow_)):
        # resample if len not enough or more
        if len_of_str[i]!=mean_of_strct_lens:
            try: tasks_follow_[i] = resample(tasks_follow_[i], n_samples=mean_of_strct_lens, replace=False)
            except: tasks_follow_[i] = resample(tasks_follow_[i], n_samples=mean_of_strct_lens, replace=True)
    # flat list
    tasks_follow = [item for sublist in tasks_follow_ for item in sublist]
    # rem temp params
    del tasks_follow_, len_of_str, mean_of_strct_lens
    print ("number of 'follow' sentences", len(tasks_follow))

print('-----------------------------------------------------')
#----------------------------------------------------------------------------------------------
# Out:
# number of 'take' sentences 10868604
# number of 'find' sentences 104720
# number of 'guide' sentences 88128
# number of 'follow' sentences 68544
# -----------------------------------------------------

# %% [markdown]
# # Resampling

# %%
# ################################################################################################################
#                                                  RESAMPLING                                                    #
# ################################################################################################################

print('resampling and appending all the task sentences into one list')
tasks = []
if len(tasks_go)>1:
    # resample
    try: tasks_go = resample(tasks_go, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_go = resample(tasks_go, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_go[i])
    # rm temp params
    del tasks_go
if len(tasks_take)>1:
    # resample
    try: tasks_take = resample(tasks_take, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_take = resample(tasks_take, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_take[i])
    # rm temp params
    del tasks_take
if len(tasks_find)>1:
    # resample
    try: tasks_find = resample(tasks_find, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_find = resample(tasks_find, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_find[i])
    # rm temp params
    del tasks_find
if len(tasks_answer)>1:
    # resample
    try: tasks_answer = resample(tasks_answer, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_answer = resample(tasks_answer, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_answer[i])
    # rm temp params
    del tasks_answer
if len(tasks_tell)>1:
    # resample
    try: tasks_tell = resample(tasks_tell, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_tell = resample(tasks_tell, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_tell[i])
    # rm temp params
    del tasks_tell
if len(tasks_meet)>1:
    # resample
    try: tasks_meet = resample(tasks_meet, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_meet = resample(tasks_meet, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_meet[i])
    # rm temp params
    del tasks_meet
if len(tasks_follow)>1:
    # resample
    try: tasks_follow = resample(tasks_follow, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_follow = resample(tasks_follow, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_follow[i])
    # rm temp params
    del tasks_follow
if len(tasks_guide)>1:
    # resample
    try: tasks_guide = resample(tasks_guide, replace=False, n_samples=n_samples_per_intent, random_state=random_state)
    except ValueError: tasks_guide = resample(tasks_guide, replace=True, n_samples=n_samples_per_intent, random_state=random_state)
    # append to main list
    for i in range(n_samples_per_intent): tasks.append(tasks_guide[i])
    # rm temp params
    del tasks_guide

print('-----------------------------------------------------')
# Out:
# resampling and appending all the task sentences into one list
# -----------------------------------------------------

# %%
tasks
# Out:
# ['hand -Btake- the cloth -Bobject- to me -Bperson-',
#  'set -Btake- the sugar -Bobject- on the stool -Bdestination-',
#  'bring -Btake- me -Bperson- the book -Bobject- from the parlour -Bsource-',
#  'deliver -Btake- the bread -Bobject- to faith -Bperson- at the door -Bdestination-',
#  'take -Btake- the forks -Bobject- to the bathroom -Bdestination-',
#  'set -Btake- the cream -Bobject- on the table -Bdestination-',
#  'give -Btake- the big -Bobject- dish -Iobject- to samuel -Bperson- at the cellar -Bdestination-',
#  'put -Btake- coke -Bobject- on the television -Bdestination-',
#  'set -Btake- the hot -Bobject- chocolate on the beanbag -Bdestination-',
#  'put -Btake- the grapes -Bobject- on the bookshelf -Bdestination-',
#  'leave -Btake- the milk -Bobject- on the washing -Bdestination- machine -Idestination-',
#  'deliver -Btake- the laptop -Bobject- to me -Bperson-',
#  'grasp -Btake- the almond -Bobject- from the oven -Bsource- to the drawing -Bdestination- room -Idestination-',
#  'give -Btake- to rosie -Bperson- at the sink -Bdestination- the toothbrush -Bobject- from the couch -Bsource-',
#  'take -Btake- the blueberries -Bobject- to the kitchen -Bdestination- chair -Idestination-',
#  'put -Btake- the wine -Bobject- on the television -Bdestination-',
#  'put -Btake- the kleenex -Bobject- on the center -Bdestination- table -Idestination-',
#  'leave -Btake- the rice -Bobject- on the table -Bdestination-',
#  'grasp -Btake- the crackers -Bobject-',
#  'grasp -Btake- the pizza -Bobject-',
#  'set -Btake- blueberries -Bobject- on the stool -Bdestination-',
#  'bring -Btake- the chocolate -Bobject- egg -Iobject- to me -Bperson-',
#  'grasp -Btake- the magazine -Bobject- from the bedroom -Bsource-',
#  'leave -Btake- the manju -Bobject- on the cabinet -Bdestination-',
#  'get -Btake- the manju -Bobject- from the stool -Bsource-',
#  'put -Btake- the wine -Bobject- on the stove -Bdestination-',
#  'grasp -Btake- the knives -Bobject- from the radiator -Bsource-',
#  'pick -Btake- up the juice -Bobject- to the sideboard -Bdestination-',
#  'take -Btake- the pen -Bobject- from the dishwasher -Bsource- to the dryer -Bdestination-',
#  'take -Btake- the chips -Bobject- from the bar -Bsource-',
#  'hand -Btake- the lemons -Bobject- to seth -Bperson- at the dryer -Bdestination-',
#  'deliver -Btake- the milk -Bobject- to daniel -Bperson-',
#  'bring -Btake- the whiteboard -Bobject- cleaner -Iobject- to henry -Bperson- at the table -Bdestination-',
#  'get -Btake- the sprite -Bobject- from the living -Bsource- room -Isource- table -Isource-',
#  'grasp -Btake- the book -Bobject-',
#  'bring -Btake- the toilet -Bobject- paper -Iobject- to luke -Bperson- at the bedroom -Bdestination- chair -Idestination-',
#  'give -Btake- to nathan -Bperson- at the bookcase -Bdestination- the toothbrush -Bobject- from the oven -Bsource-',
#  'bring -Btake- the candies -Bobject- to lucy -Bperson-',
#  'hand -Btake- over the strawberries -Bobject- to me -Bperson-',
#  'pick -Btake- up the cheese -Bobject-',
#  'place -Btake- the big -Bobject- dish -Iobject- on the bench -Bdestination-',
#  'bring -Btake- the banana -Bobject- to sienna -Bperson-',
#  'pick -Btake- up the cookies -Bobject-',
#  'pick -Btake- up the bread -Bobject- to the stove -Bdestination-',
#  'hand -Btake- over the cream -Bobject- to alex -Bperson- at the balcony -Bdestination-',
#  'pick -Btake- up the charger -Bobject- from the closet -Bsource- to the master -Bdestination- bedroom -Idestination-',
#  'get -Btake- the pen -Bobject- from the entrance -Bsource-',
#  'place -Btake- the whisky -Bobject- on the oven -Bdestination-',
#  'deliver -Btake- the strawberry -Bobject- to matthew -Bperson-',
#  'get -Btake- the ham -Bobject- burger -Iobject- from the bedroom -Bsource-',
#  'pick -Btake- up the toiletries -Bobject- from the side -Bsource- table -Isource- to the oven -Bdestination-',
#  'bring -Btake- the food -Bobject- to adam -Bperson- at the wardrobe -Bdestination-',
#  'leave -Btake- cups -Bobject- on the television -Bdestination-',
#  'get -Btake- the magazine -Bobject- to the beanbag -Bdestination-',
#  'grasp -Btake- the charger -Bobject- from the tv -Bsource- stand -Isource-',
#  'leave -Btake- the shampoo -Bobject- on the counter -Bdestination-',
#  'bring -Btake- me -Bperson- the coffee -Bobject- from the bedside -Bsource-',
#  'put -Btake- the kleenex -Bobject- on the stool -Bdestination-',
#  'give -Btake- me -Bperson- the yogurt -Bobject- from the box -Bsource- room -Isource-',
#  'give -Btake- the toilet -Bobject- paper -Iobject- to thomas -Bperson- at the stove -Bdestination-',
#  'give -Btake- to erika -Bperson- at the counter -Bdestination- the dryer -Bobject- from the side -Bsource- table -Isource-',
#  'give -Btake- the cookies -Bobject- to me -Bperson-',
#  'grasp -Btake- the plates -Bobject- to the hallway -Bdestination-',
#  'put -Btake- book -Bobject- on the dining -Bdestination- table -Idestination-',
#  'retrieve -Btake- the food -Bobject- from the master -Bsource- bedroom -Isource-',
#  'leave -Btake- the whiteboard -Bobject- cleaner -Iobject- on the cupboard -Bdestination-',
#  'get -Btake- the manju -Bobject- from the door -Bsource-',
#  'grasp -Btake- the sprite -Bobject- to the office -Bdestination-',
#  'bring -Btake- the ham -Bobject- to john -Bperson- at the parlour -Bdestination-',
#  'leave -Btake- the almonds -Bobject- on the bedroom -Bdestination- chair -Idestination-',
#  'place -Btake- orange -Bobject- on the center -Bdestination- table -Idestination-',
#  'bring -Btake- the chocolate -Bobject- tablet -Iobject- to joshua -Bperson-',
#  'leave -Btake- the lemon -Bobject- on the oven -Bdestination-',
#  'take -Btake- the toiletries -Bobject- from the bedside -Bsource-',
#  'get -Btake- the cloth -Bobject- from the dressing -Bsource- table -Isource-',
#  'hand -Btake- the strawberries -Bobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the sugar -Bobject- from the kitchen -Bsource- table -Isource-',
#  'grasp -Btake- the plate -Bobject- to the side -Bdestination- shelf -Idestination-',
#  'take -Btake- the chocolate -Bobject- tablet -Iobject- from the dressing -Bsource- table -Isource-',
#  'bring -Btake- me -Bperson- the pringles -Bobject-',
#  'hand -Btake- the soap -Bobject- to me -Bperson-',
#  'give -Btake- the chocolate -Bobject- tablet -Iobject- to katie -Bperson- at the entrance -Bdestination-',
#  'take -Btake- the drink -Bobject- to alexander -Bperson-',
#  'take -Btake- the comb -Bobject- from the chair -Bsource-',
#  'deliver -Btake- the rice -Bobject- to me -Bperson-',
#  'get -Btake- the peaches -Bobject- from the library -Bsource-',
#  'set -Btake- lotion -Bobject- on the washing -Bdestination- machine -Idestination-',
#  'deliver -Btake- the big -Bobject- dish -Iobject- to oscar -Bperson-',
#  'give -Btake- the strawberries -Bobject- to alice -Bperson- at the bench -Bdestination-',
#  'bring -Btake- the kleenex -Bobject- to harrison -Bperson- at the rocking -Bdestination- chair -Idestination-',
#  'set -Btake- the strawberries -Bobject- on the rocking -Bdestination- chair -Idestination-',
#  'take -Btake- the sake -Bobject- to sienna -Bperson-',
#  'hand -Btake- the food -Bobject- to mia -Bperson- at the dishwasher -Bdestination-',
#  'hand -Btake- over the shampoo -Bobject- to me -Bperson-',
#  'deliver -Btake- the rice -Bobject- to the washing -Bdestination- machine -Idestination-',
#  'set -Btake- the ham -Bobject- burger -Iobject- on the sofa -Bdestination-',
#  'pick -Btake- up the notebook -Bobject-',
#  'grasp -Btake- the lotion -Bobject- from the dishwasher -Bsource-',
#  'give -Btake- me -Bperson- the food -Bobject- from the radiator -Bsource-',
#  'bring -Btake- to jacob -Bperson- at the cabinet -Bdestination- the grapes -Bobject- from the dryer -Bsource-',
#  'give -Btake- to rose -Bperson- at the closet -Bdestination- the toothbrush -Bobject- from the side -Bsource- table -Isource-',
#  'take -Btake- the sponge -Bobject- to the drawer -Bdestination-',
#  'give -Btake- to harry -Bperson- at the counter -Bdestination- the pepper -Bobject- from the oven -Bsource-',
#  'deliver -Btake- the chewing -Bobject- gum -Iobject- to the ballroom -Bdestination-',
#  'give -Btake- me -Bperson- the grapes -Bobject- from the washer -Bsource-',
#  'grasp -Btake- the dryer -Bobject-',
#  'deliver -Btake- the bananas -Bobject- to luke -Bperson-',
#  'deliver -Btake- the notebook -Bobject- to sophia -Bperson- at the side -Bdestination- table -Idestination-',
#  'deliver -Btake- the book -Bobject- to tyler -Bperson-',
#  'deliver -Btake- the grapes -Bobject- to toby -Bperson-',
#  'deliver -Btake- the grapes -Bobject- to olivia -Bperson-',
#  'bring -Btake- me -Bperson- the cheese -Bobject- from the futon -Bsource-',
#  'take -Btake- the cups -Bobject- to the kitchen -Bdestination- table -Idestination-',
#  'pick -Btake- up the vodka -Bobject- from the tv -Bsource- stand -Isource- to the oven -Bdestination-',
#  'hand -Btake- over the milk -Bobject- to me -Bperson-',
#  'hand -Btake- the choco -Bobject- flakes -Iobject- to john -Bperson- at the sink -Bdestination-',
#  'retrieve -Btake- the lemons -Bobject- from the nightstand -Bsource-',
#  'grasp -Btake- the chewing -Bobject- gums -Iobject- to the shed -Bdestination-',
#  'leave -Btake- the chocolate -Bobject bar -Iobject- on the side -Bdestination- shelf -Idestination-',
#  'deliver -Btake- the lemons -Bobject- to arthur -Bperson- at the rocking -Bdestination- chair -Idestination-',
#  'give -Btake- the plate -Bobject- to jacob -Bperson-',
#  'take -Btake- the tea -Bobject- from the closet -Bsource- to the tv -Bdestination- stand -Idestination-',
#  'take -Btake- the charger -Bobject- to blake -Bperson-',
#  'take -Btake- the banana -Bobject- to the bedchamber -Bdestination-',
#  'deliver -Btake- the almonds -Bobject- to me -Bperson-',
#  'set -Btake- bananas -Bobject- on the nightstand -Bdestination-',
#  'pick -Btake- up the oranges -Bobject- from the master -Bsource- bedroom -Isource- to the shed -Bdestination-',
#  'leave -Btake- drink -Bobject- on the bedchamber -Bdestination-',
#  'hand -Btake- over the apples -Bobject- to brooke -Bperson- at the bedside -Bdestination-',
#  'hand -Btake- over the glass -Bobject- to adam -Bperson- at the den -Bdestination-',
#  'bring -Btake- the bananas -Bobject- to samuel -Bperson-',
#  'deliver -Btake- the comb -Bobject- to harry -Bperson- at the drawer -Bdestination-',
#  'take -Btake- the manju -Bobject- to the sideboard -Bdestination-',
#  'give -Btake- the hot -Bobject- chocolate to me -Bperson-',
#  'bring -Btake- to theo -Bperson- at the living -Bdestination- room -Idestination- table -Idestination- the crackers -Bobject- from the tv -Bsource- stand -Isource-',
#  'take -Btake- the chocolate -Bobject- egg -Iobject- from the closet -Bsource-',
#  'deliver -Btake- the knife -Bobject- to ella -Bperson- at the laundry -Bdestination-',
#  'deliver -Btake- the ham -Bobject- to joseph -Bperson-',
#  'bring -Btake- the cup -Bobject- to ryan -Bperson-',
#  'bring -Btake- the big -Bobject- dish -Iobject- to aaron -Bperson- at the office -Bdestination-',
#  'put -Btake- chocolate -Bobject- egg -Iobject- on the kitchen -Bdestination- cabinet -Idestination-',
#  'put -Btake- the toilet -Bobject- paper -Iobject- to the bedside -Bdestination-',
#  'leave -Btake- the donuts -Bobject- on the bedroom -Bdestination- chair -Idestination-',
#  'hand -Btake- the mints -Bobject- to tyler -Bperson- at the pantry -Bdestination-',
#  'bring -Btake- me -Bperson- the chips -Bobject-',
#  'pick -Btake- up the ham -Bobject- to the rocking -Bdestination- chair -Idestination-',
#  'hand -Btake- over the grapes -Bobject- to harvey -Bperson- at the counter -Bdestination-',
#  'bring -Btake- the grapes -Bobject- to me -Bperson-',
#  'take -Btake- the coffee -Bobject- to william -Bperson-',
#  'bring -Btake- to barbara -Bperson- at the coffee -Bdestination- table -Idestination- the sprite -Bobject- from the dryer -Bsource-',
#  'pick -Btake- up the peanuts -Bobject-',
#  'grasp -Btake- the rice -Bobject- from the shower -Bsource-',
#  'set -Btake- the ham -Bobject- burger -Iobject- on the stove -Bdestination-',
#  'give -Btake- the towel -Bobject- to emilia -Bperson-',
#  'bring -Btake- me -Bperson- the containers -Bobject- from the dormitory -Bsource- room -Isource-',
#  'retrieve -Btake- the choco -Bobject- flakes -Iobject- from the sofa -Bsource-',
#  'take -Btake- the ham -Bobject- burger -Iobject- from the dishwasher -Bsource- to the side -Bdestination- table -Idestination-',
#  'give -Btake- me -Bperson- the toothpaste -Bobject-',
#  'give -Btake- me -Bperson- the bottle -Bobject-',
#  'deliver -Btake- the cake -Bobject- to michael -Bperson- at the center -Bdestination- table -Idestination-',
#  'get -Btake- the chocolate -Bobject- tablet -Iobject- from the dishwasher -Bsource- to the tv -Bdestination- stand -Idestination-',
#  'put -Btake- cream -Bobject- on the table -Bdestination-',
#  'bring -Btake- to oliver -Bperson- at the sink -Bdestination- the bread -Bobject- from the shed -Bsource-',
#  'grasp -Btake- the lemon -Bobject- to the lawn -Bdestination-',
#  'pick -Btake- up the apples -Bobject-',
#  'deliver -Btake- the toiletries -Bobject- to madison -Bperson-',
#  'place -Btake- lemon -Bobject- on the nightstand -Bdestination-',
#  'pick -Btake- up the hot -Bobject- chocolate from the master -Bsource- bedroom -Isource- to the shed -Bdestination-',
#  'pick -Btake- up the iced -Bobject- tea -Iobject- from the cellar -Bsource-',
#  'give -Btake- the choco -Bobject- flakes -Iobject- to amelia -Bperson-',
#  'take -Btake- the toiletries -Bobject- to amber -Bperson-',
#  'give -Btake- me -Bperson- the donuts -Bobject- from the dormitory -Bsource- room -Isource-',
#  'get -Btake- the sushi -Bobject- to the basement -Bdestination-',
#  'deliver -Btake- the crackers -Bobject- to me -Bperson-',
#  'set -Btake- containers -Bobject- on the bedchamber -Bdestination-',
#  'get -Btake- the big -Bobject- dish -Iobject- to the entrance -Bdestination-',
#  'give -Btake- me -Bperson- the sake -Bobject-',
#  'hand -Btake- the blueberries -Bobject- to me -Bperson-',
#  'pick -Btake- up the paprika -Bobject-',
#  'put -Btake- the magazine -Bobject- to the window -Bdestination-',
#  'pick -Btake- up the chocolate -Bobject- egg -Iobject- from the drawing -Bsource- room -Isource- to the shed -Bdestination-',
#  'bring -Btake- the charger -Bobject- to evan -Bperson- at the futon -Bdestination-',
#  'bring -Btake- the oranges -Bobject- to me -Bperson-',
#  'grasp -Btake- the ham -Bobject-',
#  'deliver -Btake- the lemonade -Bobject- to the wardrobe -Bdestination-',
#  'hand -Btake- over the watermelon -Bobject- to me -Bperson-',
#  'take -Btake- the sugar -Bobject- from the washing -Bsource- machine -Isource-',
#  'get -Btake- the soap -Bobject- to the dishwasher -Bdestination-',
#  'deliver -Btake- the shampoo -Bobject- to erik -Bperson- at the master -Bdestination- bedroom -Idestination-',
#  'hand -Btake- the tray -Bobject- to me -Bperson-',
#  'put -Btake- yogurt -Bobject- on the kitchen -Bdestination- chair -Idestination-',
#  'bring -Btake- me -Bperson- the vodka -Bobject- from the laundry -Bsource-',
#  'pick -Btake- up the pen -Bobject- from the playroom -Bsource-',
#  'bring -Btake- me -Bperson- the containers -Bobject-',
#  'give -Btake- to noah -Bperson- at the sink -Bdestination- the bowl -Bobject- from the shed -Bsource-',
#  'bring -Btake- the noodles -Bobject- to max -Bperson- at the entrance -Bdestination-',
#  'deliver -Btake- the toothbrush -Bobject- to me -Bperson-',
#  'grasp -Btake- the cream -Bobject- from the side -Bsource- table -Isource- to the dryer -Bdestination-',
#  'put -Btake- apples -Bobject- on the beanbag -Bdestination-',
#  'take -Btake- the ham -Bobject- from the music -Bsource- room -Isource-',
#  'hand -Btake- the dryer -Bobject- to me -Bperson-',
#  'deliver -Btake- the dryer -Bobject- to the library -Bdestination-',
#  'hand -Btake- the lemons -Bobject- to me -Bperson-',
#  'deliver -Btake- the sushi -Bobject- to joseph -Bperson-',
#  'take -Btake- the can -Bobject- from the master -Bsource- bedroom -Isource- to the corridor -Bdestination-',
#  'give -Btake- the candies -Bobject- to me -Bperson-',
#  'deliver -Btake- the food -Bobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the tea -Bobject- from the pantry -Bsource-',
#  'give -Btake- the sugar -Bobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the cheese -Bobject-',
#  'get -Btake- the cup -Bobject- from the couch -Bsource- to the dryer -Bdestination-',
#  'get -Btake- the rum -Bobject- from the bookcase -Bsource-',
#  'set -Btake- container -Bobject- on the bookshelf -Bdestination-',
#  'hand -Btake- the plate -Bobject- to jacob -Bperson- at the washing -Bdestination- machine -Idestination-',
#  'bring -Btake- to florence -Bperson- at the closet -Bdestination- the paprika -Bobject- from the side -Bsource- table -Isource-',
#  'put -Btake- the container -Bobject- on the dressing -Bdestination- table -Idestination-',
#  'pick -Btake- up the plate -Bobject- from the playroom -Bsource-',
#  'pick -Btake- up the blackberry -Bobject- to the drawer -Bdestination-',
#  'deliver -Btake- the peanuts -Bobject- to sienna -Bperson- at the closet -Bdestination-',
#  'place -Btake- whiteboard -Bobject- cleaner -Iobject- on the futon -Bdestination-',
#  'deliver -Btake- the almond -Bobject- to the beanbag -Bdestination-',
#  'pick -Btake- up the books -Bobject-',
#  'leave -Btake- ham -Bobject- burger -Iobject- on the drawer -Bdestination-',
#  'get -Btake- the cream -Bobject- to the rocking -Bdestination- chair -Idestination-',
#  'pick -Btake- up the iced -Bobject- tea -Iobject- to the dormitory -Bdestination- room -Idestination-',
#  'put -Btake- the chocolate -Bobject- egg -Iobject- to the dining -Bdestination- table -Idestination-',
#  'give -Btake- the newspaper -Bobject- to me -Bperson-',
#  'pick -Btake- up the pencil -Bobject- to the porch -Bdestination-',
#  'get -Btake- the cheese -Bobject- from the table -Bsource-',
#  'give -Btake- to skyler -Bperson- at the desk -Bdestination- the apples -Bobject- from the corridor -Bsource-',
#  'hand -Btake- the crackers -Bobject- to louis -Bperson- at the futon -Bdestination-',
#  'hand -Btake- over the toothpaste -Bobject- to me -Bperson-',
#  'deliver -Btake- the salt -Bobject- to edward -Bperson- at the lamp -Bdestination-',
#  'bring -Btake- me -Bperson- the lemon -Bobject- from the rocking -Bsource- chair -Isource-',
#  'grasp -Btake- the strawberry -Bobject- from the living -Bsource- room -Isource-',
#  'give -Btake- the pringles -Bobject- to me -Bperson-',
#  'give -Btake- the candy -Bobject- to brian -Bperson-',
#  'get -Btake- the manju -Bobject- to the nightstand -Bdestination-',
#  'retrieve -Btake- the senbei -Bobject- from the window -Bsource-',
#  'hand -Btake- the tea -Bobject- to me -Bperson-',
#  'give -Btake- me -Bperson- the whiteboard -Bobject- cleaner -Iobject-',
#  'pick -Btake- up the containers -Bobject- from the oven -Bsource- to the side -Bdestination- table -Idestination-',
#  'give -Btake- me -Bperson- the pen -Bobject-',
#  'deliver -Btake- the toilet -Bobject- paper -Iobject- to liam -Bperson-',
#  'take -Btake- the notebook -Bobject- from the prayer -Bsource- room -Isource-',
#  'put -Btake- the pringles -Bobject- on the dining -Bdestination- table -Idestination-',
#  'give -Btake- the pringles -Bobject- to me -Bperson-',
#  'grasp -Btake- the choco -Bobject- flakes -Iobject- from the room -Bsource-',
#  'deliver -Btake- the sponge -Bobject- to abigail -Bperson- at the door -Bdestination-',
#  'get -Btake- the magazine -Bobject- from the shed -Bsource- to the master -Bdestination- bedroom -Idestination-',
#  'bring -Btake- the biscuits -Bobject- to lewis -Bperson-',
#  'set -Btake- the cream -Bobject- on the bedchamber -Bdestination-',
#  'set -Btake- the kleenex -Bobject- on the drawer -Bdestination-',
#  'grasp -Btake- the lemons -Bobject- to the bar -Bdestination-',
#  'give -Btake- me -Bperson- the tray -Bobject-',
#  'give -Btake- me -Bperson- the bread -Bobject-',
#  'deliver -Btake- the knives -Bobject- to freddie -Bperson-',
#  'give -Btake- the peaches -Bobject- to tommy -Bperson- at the counter -Bdestination-',
#  'get -Btake- the shampoo -Bobject- from the beanbag -Bsource-',
#  'take -Btake- the container -Bobject- from the dishwasher -Bsource-',
#  'deliver -Btake- the cheese -Bobject- to me -Bperson-',
#  'pick -Btake- up the ham -Bobject- burger -Iobject- from the dryer -Bsource- to the master -Bdestination- bedroom -Idestination-',
#  'leave -Btake- the cans -Bobject- on the washing -Bdestination- machine -Idestination-',
#  'give -Btake- to amelie -Bperson- at the door -Bdestination- the magazine -Bobject- from the side -Bsource- table -Isource-',
#  'deliver -Btake- the donuts -Bobject- to louis -Bperson- at the kitchen -Bdestination- chair -Idestination-',
#  'set -Btake- the toiletries -Bobject- on the stove -Bdestination-',
#  'deliver -Btake- the chewing -Bobject- gums -Iobject- to amy -Bperson-',
#  'grasp -Btake- the mints -Bobject- from the oven -Bsource- to the dishwasher -Bdestination-',
#  'place -Btake- rum -Bobject- on the oven -Bdestination-',
#  'place -Btake- the milk -Bobject- on the bookcase -Bdestination-',
#  'give -Btake- the lotion -Bobject- to me -Bperson-',
#  'get -Btake- the peach -Bobject- from the dishwasher -Bsource- to the shed -Bdestination-',
#  'take -Btake- the onions -Bobject- from the tv -Bsource- stand -Isource- to the corridor -Bdestination-',
#  'grasp -Btake- the almond -Bobject- from the bench -Bsource-',
#  'deliver -Btake- the fork -Bobject- to scarlett -Bperson- at the cellar -Bdestination-',
#  'hand -Btake- over the laptop -Bobject- to jackie -Bperson- at the window -Bdestination-',
#  'retrieve -Btake- the salt -Bobject- from the hall -Bsource-',
#  'pick -Btake- up the peanut -Bobject- from the bedroom -Bsource-',
#  'bring -Btake- the choco -Bobject- flakes -Iobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the cups -Bobject-',
#  'give -Btake- the strawberries -Bobject- to olivia -Bperson- at the closet -Bdestination-',
#  'grasp -Btake- the cheese -Bobject- to the patio -Bdestination-',
#  'get -Btake- the onion -Bobject- from the drawing -Bsource- room -Isource- to the tv -Bdestination- stand -Idestination-',
#  'bring -Btake- the container -Bobject- to me -Bperson-',
#  'hand -Btake- over the crackers -Bobject- to daniel -Bperson- at the fridge -Bdestination-',
#  'pick -Btake- up the lemons -Bobject-',
#  'bring -Btake- the sake -Bobject- to isabelle -Bperson-',
#  'bring -Btake- the juice -Bobject- to dylan -Bperson- at the master -Bdestination- bedroom -Idestination-',
#  'bring -Btake- the cookies -Bobject- to me -Bperson-',
#  'hand -Btake- the newspaper -Bobject- to me -Bperson-',
#  'take -Btake- the senbei -Bobject- from the drawing -Bsource- room -Isource- to the master -Bdestination- bedroom -Idestination-',
#  'place -Btake- the yogurt -Bobject- on the drawer -Bdestination-',
#  'hand -Btake- the pear -Bobject- to john -Bperson- at the kitchen -Bdestination- table -Idestination-',
#  'give -Btake- me -Bperson- the peach -Bobject-',
#  'place -Btake- peanuts -Bobject- on the bench -Bdestination-',
#  'pick -Btake- up the can -Bobject- from the couch -Bsource- to the closet -Bdestination-',
#  'bring -Btake- the choco -Bobject- flakes -Iobject- to barbara -Bperson-',
#  'set -Btake- sushi -Bobject- on the bedchamber -Bdestination-',
#  'place -Btake- the hot -Bobject- chocolate on the kitchen -Bdestination- table -Idestination-',
#  'hand -Btake- over the pringles -Bobject- to me -Bperson-',
#  'get -Btake- the charger -Bobject- to the guestroom -Bdestination-',
#  'grasp -Btake- the watermelon -Bobject- from the window -Bsource-',
#  'bring -Btake- me -Bperson- the coke -Bobject-',
#  'bring -Btake- the lemon -Bobject- to lily -Bperson-',
#  'deliver -Btake- the lemon -Bobject- to harrison -Bperson-',
#  'grasp -Btake- the toiletries -Bobject- from the sofa -Bsource-',
#  'bring -Btake- the chips -Bobject- to me -Bperson-',
#  'place -Btake- the watermelon -Bobject- on the kitchen -Bdestination- chair -Idestination-',
#  'deliver -Btake- the wine -Bobject- to emma -Bperson-',
#  'hand -Btake- over the coffee -Bobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the strawberries -Bobject- from the basement -Bsource-',
#  'set -Btake- the chocolate -Bobject bar -Iobject- on the rocking -Bdestination- chair -Idestination-',
#  'set -Btake- bowl -Bobject- on the side -Bdestination- table -Idestination-',
#  'grasp -Btake- the wine -Bobject- from the door -Bsource-',
#  'deliver -Btake- the newspaper -Bobject- to arthur -Bperson-',
#  'bring -Btake- to madison -Bperson- at the kitchen -Bdestination- table -Idestination- the pizza -Bobject- from the oven -Bsource-',
#  'take -Btake- the charger -Bobject- to noah -Bperson-',
#  'set -Btake- container -Bobject- on the counter -Bdestination-',
#  'bring -Btake- the toiletries -Bobject- to me -Bperson-',
#  'deliver -Btake- the notebook -Bobject- to joseph -Bperson-',
#  'give -Btake- the cream -Bobject- to luke -Bperson-',
#  'bring -Btake- to ryan -Bperson- at the closet -Bdestination- the magazine -Bobject- from the dryer -Bsource-',
#  'get -Btake- the tablet -Bobject- from the dishwasher -Bsource- to the closet -Bdestination-',
#  'hand -Btake- the comb -Bobject- to me -Bperson-',
#  'take -Btake- the cider -Bobject- to the radiator -Bdestination-',
#  'set -Btake- bottle -Bobject- on the bookcase -Bdestination-',
#  'pick -Btake- up the candies -Bobject- to the stove -Bdestination-',
#  'leave -Btake- the sugar -Bobject- on the dryer -Bdestination-',
#  'bring -Btake- the toothbrush -Bobject- to me -Bperson-',
#  'retrieve -Btake- the towel -Bobject- from the cellar -Bsource-',
#  'deliver -Btake- the hot -Bobject- chocolate to me -Bperson-',
#  'give -Btake- the blueberries -Bobject- to me -Bperson-',
#  'set -Btake- the crackers -Bobject- on the dishwasher -Bdestination-',
#  'bring -Btake- me -Bperson- the noodles -Bobject- from the telephone -Bsource-',
#  'deliver -Btake- the banana -Bobject- to the balcony -Bdestination-',
#  'hand -Btake- over the salt -Bobject- to me -Bperson-',
#  'grasp -Btake- the tray -Bobject- from the parlour -Bsource-',
#  'pick -Btake- up the donuts -Bobject- from the master -Bsource- bedroom -Isource- to the dishwasher -Bdestination-',
#  'get -Btake- the pencil -Bobject- to the cellar -Bdestination-',
#  'retrieve -Btake- the food -Bobject- from the telephone -Bsource-',
#  'hand -Btake- over the burger -Bobject- to me -Bperson-',
#  'pick -Btake- up the cup -Bobject- from the nightstand -Bsource-',
#  'take -Btake- the peanuts -Bobject- from the fridge -Bsource-',
#  'get -Btake- the towel -Bobject- from the master -Bsource- bedroom -Isource- to the dryer -Bdestination-',
#  'get -Btake- the rice -Bobject- from the prayer -Bsource- room -Isource-',
#  'set -Btake- the cream -Bobject- on the stove -Bdestination-',
#  'give -Btake- to aaron -Bperson- at the sofa -Bdestination- the big -Bobject- dish -Iobject- from the oven -Bsource-',
#  'deliver -Btake- the pringles -Bobject- to the bench -Bdestination-',
#  'bring -Btake- the coffee -Bobject- to sophia -Bperson- at the kitchen -Bdestination- table -Idestination-',
#  'place -Btake- the pie -Bobject- on the bench -Bdestination-',
#  'grasp -Btake- the peaches -Bobject- to the kitchen -Bdestination- cabinet -Idestination-',
#  'deliver -Btake- the trays -Bobject- to the sink -Bdestination-',
#  'pick -Btake- up the choco -Bobject- flakes -Iobject- to the bench -Bdestination-',
#  'take -Btake- the crackers -Bobject- from the master -Bsource- bedroom -Isource- to the shed -Bdestination-',
#  'deliver -Btake- the biscuit -Bobject- to amber -Bperson-',
#  'hand -Btake- the toiletries -Bobject- to me -Bperson-',
#  'bring -Btake- the containers -Bobject- to me -Bperson-',
#  'get -Btake- the coffee -Bobject- to the den -Bdestination-',
#  'deliver -Btake- the burger -Bobject- to me -Bperson-',
#  'pick -Btake- up the chewing -Bobject- gums -Iobject- to the drawing -Bdestination- room -Idestination-',
#  'deliver -Btake- the coke -Bobject- to daniel -Bperson- at the washer -Bdestination-',
#  'place -Btake- the blueberries -Bobject- on the dryer -Bdestination-',
#  'leave -Btake- tray -Bobject- on the cupboard -Bdestination-',
#  'bring -Btake- to amber -Bperson- at the kitchen -Bdestination- cabinet -Idestination- the newspaper -Bobject- from the side -Bsource- table -Isource-',
#  'pick -Btake- up the drink -Bobject-',
#  'grasp -Btake- the almond -Bobject- to the counter -Bdestination-',
#  'grasp -Btake- the toothpaste -Bobject- from the cellar -Bsource-',
#  'bring -Btake- the almonds -Bobject- to me -Bperson-',
#  'give -Btake- the knife -Bobject- to me -Bperson-',
#  'deliver -Btake- the bread -Bobject- to sophie -Bperson-',
#  'give -Btake- the toothpaste -Bobject- to amy -Bperson- at the kitchen -Bdestination- table -Idestination-',
#  'deliver -Btake- the rice -Bobject- to jane -Bperson-',
#  'hand -Btake- the whisky -Bobject- to harrison -Bperson- at the living -Bdestination- room -Idestination- table -Idestination-',
#  'grasp -Btake- the cheese -Bobject- to the shower -Bdestination-',
#  'bring -Btake- the onion -Bobject- to florence -Bperson- at the television -Bdestination-',
#  'place -Btake- the lemonade -Bobject- on the washing -Bdestination- machine -Idestination-',
#  'take -Btake- the apple -Bobject- from the master -Bsource- bedroom -Isource- to the oven -Bdestination-',
#  'give -Btake- me -Bperson- the cookies -Bobject-',
#  'set -Btake- the peanuts -Bobject- on the beanbag -Bdestination-',
#  'hand -Btake- over the sake -Bobject- to me -Bperson-',
#  'set -Btake- the toothpaste -Bobject- on the bookshelf -Bdestination-',
#  'put -Btake- the sprite -Bobject- to the playroom -Bdestination-',
#  'bring -Btake- me -Bperson- the blackberries -Bobject-',
#  'set -Btake- book -Bobject- on the desk -Bdestination-',
#  'put -Btake- the coke -Bobject- to the cloakroom -Bdestination-',
#  'pick -Btake- up the mints -Bobject- to the room -Bdestination-',
#  'hand -Btake- over the rum -Bobject- to oliver -Bperson- at the radiator -Bdestination-',
#  'retrieve -Btake- the glass -Bobject- from the nightstand -Bsource-',
#  'give -Btake- the bowl -Bobject- to adam -Bperson-',
#  'pick -Btake- up the food -Bobject- to the television -Bdestination-',
#  'give -Btake- the tablet -Bobject- to mia -Bperson- at the door -Bdestination-',
#  'pick -Btake- up the bread -Bobject-',
#  'pick -Btake- up the crackers -Bobject-',
#  'bring -Btake- to isabelle -Bperson- at the nightstand -Bdestination- the rice -Bobject- from the shed -Bsource-',
#  'bring -Btake- the bananas -Bobject- to ella -Bperson-',
#  'get -Btake- the choco -Bobject- flakes -Iobject- from the drawer -Bsource-',
#  'hand -Btake- over the kleenex -Bobject- to me -Bperson-',
#  'put -Btake- the toilet -Bobject- paper -Iobject- to the garage -Bdestination-',
#  'pick -Btake- up the cookies -Bobject- from the drawing -Bsource- room -Isource- to the oven -Bdestination-',
#  'get -Btake- the biscuits -Bobject- from the drawing -Bsource- room -Isource- to the closet -Bdestination-',
#  'deliver -Btake- the whiteboard -Bobject- cleaner -Iobject- to edward -Bperson-',
#  'deliver -Btake- the crackers -Bobject- to erika -Bperson-',
#  'give -Btake- the cake -Bobject- to daisy -Bperson- at the entrance -Bdestination-',
#  'give -Btake- the plate -Bobject- to me -Bperson-',
#  'get -Btake- the whiteboard -Bobject- cleaner -Iobject- to the desk -Bdestination-',
#  'put -Btake- the fork -Bobject- on the cabinet -Bdestination-',
#  'bring -Btake- the cheese -Bobject- to me -Bperson-',
#  'deliver -Btake- the peach -Bobject- to paige -Bperson- at the patio -Bdestination-',
#  'grasp -Btake- the trays -Bobject- from the dryer -Bsource- to the corridor -Bdestination-',
#  'bring -Btake- me -Bperson- the candy -Bobject-',
#  'bring -Btake- to matthew -Bperson- at the kitchen -Bdestination- chair -Idestination- the pepper -Bobject- from the side -Bsource- table -Isource-',
#  'bring -Btake- the sprite -Bobject- to amelia -Bperson- at the sun -Bdestination- room -Idestination-',
#  'grasp -Btake- the blueberry -Bobject- to the coffee -Bdestination- table -Idestination-',
#  'give -Btake- me -Bperson- the peaches -Bobject- from the bench -Bsource-',
#  'retrieve -Btake- the onions -Bobject- from the shower -Bsource-',
#  'deliver -Btake- the pringles -Bobject- to me -Bperson-',
#  'place -Btake- food -Bobject- on the living -Bdestination- room -Idestination- table -Idestination-',
#  'give -Btake- me -Bperson- the peaches -Bobject- from the entrance -Bsource-',
#  'hand -Btake- the apples -Bobject- to max -Bperson- at the rocking -Bdestination- chair -Idestination-',
#  'grasp -Btake- the laptop -Bobject-',
#  'take -Btake- the manju -Bobject- from the drawing -Bsource- room -Isource- to the master -Bdestination- bedroom -Idestination-',
#  'put -Btake- the peaches -Bobject- on the side -Bdestination- table -Idestination-',
#  'retrieve -Btake- the charger -Bobject- from the toilet -Bsource-',
#  'place -Btake- the tray -Bobject- on the dryer -Bdestination-',
#  'grasp -Btake- the pens -Bobject-',
#  'bring -Btake- me -Bperson- the drink -Bobject-',
#  'take -Btake- the newspapers -Bobject- to the telephone -Bdestination-',
#  'bring -Btake- the bottle -Bobject- to mia -Bperson-',
#  'put -Btake- the toiletries -Bobject- on the dining -Bdestination- table -Idestination-',
#  'take -Btake- the manju -Bobject- from the dressing -Bsource- table -Isource-',
#  'put -Btake- the plate -Bobject- on the stool -Bdestination-',
#  'give -Btake- the dryer -Bobject- to alice -Bperson- at the coffee -Bdestination- table -Idestination-',
#  'take -Btake- the books -Bobject- to sophia -Bperson-',
#  'take -Btake- the yogurt -Bobject- from the couch -Bsource- to the drawing -Bdestination- room -Idestination-',
#  'put -Btake- pencil -Bobject- on the fridge -Bdestination-',
#  'deliver -Btake- the orange -Bobject- to henry -Bperson-',
#  'set -Btake- the big -Bobject- dish -Iobject- on the futon -Bdestination-',
#  'place -Btake- tablet -Bobject- on the table -Bdestination-',
#  'grasp -Btake- the pear -Bobject- from the crib -Bsource-',
#  'set -Btake- pringles -Bobject- on the chair -Bdestination-',
#  'deliver -Btake- the milk -Bobject- to samantha -Bperson-',
#  'grasp -Btake- the pencil -Bobject- to the garage -Bdestination-',
#  'retrieve -Btake- the knife -Bobject- from the futon -Bsource-',
#  'get -Btake- the blackberries -Bobject- from the tv -Bsource- stand -Isource- to the dryer -Bdestination-',
#  'deliver -Btake- the lemonade -Bobject- to me -Bperson-',
#  'put -Btake- the cider -Bobject- to the bookcase -Bdestination-',
#  'bring -Btake- me -Bperson- the whisky -Bobject-',
#  'bring -Btake- the whisky -Bobject- to henry -Bperson- at the pantry -Bdestination-',
#  'hand -Btake- the newspaper -Bobject- to luke -Bperson- at the cupboard -Bdestination-',
#  'retrieve -Btake- the toilet -Bobject- paper -Iobject- from the cellar -Bsource-',
#  'take -Btake- the cup -Bobject- from the shower -Bsource-',
#  'hand -Btake- the choco -Bobject- flakes -Iobject- to me -Bperson-',
#  'grasp -Btake- the knife -Bobject-',
#  'pick -Btake- up the whisky -Bobject- from the oven -Bsource-',
#  'place -Btake- the sprite -Bobject- on the drawer -Bdestination-',
#  'hand -Btake- the paprika -Bobject- to nathan -Bperson- at the fridge -Bdestination-',
#  'deliver -Btake- the tea -Bobject- to the desk -Bdestination-',
#  'pick -Btake- up the onion -Bobject- from the shed -Bsource- to the closet -Bdestination-',
#  'leave -Btake- the cookie -Bobject- on the dishwasher -Bdestination-',
#  'put -Btake- the book -Bobject- on the cabinet -Bdestination-',
#  'hand -Btake- the milk -Bobject- to charlie -Bperson- at the cabinet -Bdestination-',
#  'give -Btake- the snacks -Bobject- to ethan -Bperson-',
#  'place -Btake- the donuts -Bobject- on the counter -Bdestination-',
#  'pick -Btake- up the sponge -Bobject- from the oven -Bsource- to the side -Bdestination- table -Idestination-',
#  'get -Btake- the candies -Bobject- from the couch -Bsource-',
#  'grasp -Btake- the snacks -Bobject- from the tv -Bsource- stand -Isource- to the shed -Bdestination-',
#  'hand -Btake- the sponge -Bobject- to me -Bperson-',
#  'bring -Btake- the peach -Bobject- to lily -Bperson-',
#  'leave -Btake- the tray -Bobject- on the stove -Bdestination-',
#  'pick -Btake- up the red -Bobject balls -Iobject- to the living -Bdestination- room -Idestination- table -Idestination-',
#  'put -Btake- the blackberry -Bobject- to the radiator -Bdestination-',
#  'give -Btake- the drink -Bobject- to henry -Bperson-',
#  'give -Btake- me -Bperson- the strawberries -Bobject- from the kitchen -Bsource-',
#  'bring -Btake- the paprika -Bobject- to jackie -Bperson-',
#  'deliver -Btake- the donuts -Bobject- to will -Bperson-',
#  'pick -Btake- up the bowls -Bobject- from the drawing -Bsource- room -Isource- to the dryer -Bdestination-',
#  'bring -Btake- me -Bperson- the laptop -Bobject- from the guestroom -Bsource-',
#  'give -Btake- the toothpaste -Bobject- to isaac -Bperson-',
#  'deliver -Btake- the cookies -Bobject- to max -Bperson- at the nightstand -Bdestination-',
#  'pick -Btake- up the wine -Bobject- from the garage -Bsource-',
#  'take -Btake- the apple -Bobject- from the guestroom -Bsource-',
#  'hand -Btake- the oranges -Bobject- to amber -Bperson- at the dormitory -Bdestination- room -Idestination-',
#  'get -Btake- the hot -Bobject- chocolate to the prayer -Bdestination- room -Idestination-',
#  'retrieve -Btake- the fork -Bobject- from the garden -Bsource-',
#  'give -Btake- me -Bperson- the cloth -Bobject-',
#  'give -Btake- me -Bperson- the chocolate -Bobject- egg -Iobject-',
#  'hand -Btake- over the container -Bobject- to me -Bperson-',
#  'grasp -Btake- the onions -Bobject- from the couch -Bsource- to the side -Bdestination- table -Idestination-',
#  'take -Btake- the container -Bobject- from the drawing -Bsource- room -Isource- to the oven -Bdestination-',
#  'give -Btake- the cream -Bobject- to elliot -Bperson- at the wardrobe -Bdestination-',
#  'leave -Btake- the pencil -Bobject- on the kitchen -Bdestination- table -Idestination-',
#  'bring -Btake- the fork -Bobject- to me -Bperson-',
#  'pick -Btake- up the noodles -Bobject- from the coffee -Bsource- table -Isource-',
#  'get -Btake- the oranges -Bobject- from the games -Bsource- room -Isource-',
#  'give -Btake- the chewing -Bobject- gums -Iobject- to daisy -Bperson-',
#  'take -Btake- the glasses -Bobject- to the sink -Bdestination-',
#  'bring -Btake- the orange -Bobject- to michael -Bperson- at the bedside -Bdestination-',
#  'bring -Btake- me -Bperson- the pepper -Bobject- from the entrance -Bsource-',
#  'grasp -Btake- the toothpaste -Bobject- to the stool -Bdestination-',
#  'place -Btake- the rice -Bobject- on the cupboard -Bdestination-',
#  'bring -Btake- me -Bperson- the pepper -Bobject-',
#  'pick -Btake- up the strawberries -Bobject- from the tv -Bsource- stand -Isource- to the dishwasher -Bdestination-',
#  'take -Btake- the cider -Bobject- from the oven -Bsource- to the dryer -Bdestination-',
#  'deliver -Btake- the pie -Bobject- to zoe -Bperson- at the garden -Bdestination-',
#  'deliver -Btake- the sponge -Bobject- to daisy -Bperson-',
#  'get -Btake- the pen -Bobject- from the closet -Bsource- to the couch -Bdestination-',
#  'hand -Btake- over the chocolate -Bobject bar -Iobject- to arthur -Bperson- at the cupboard -Bdestination-',
#  'pick -Btake- up the noodles -Bobject- from the office -Bsource-',
#  'hand -Btake- over the pizza -Bobject- to charlotte -Bperson- at the dishwasher -Bdestination-',
#  'bring -Btake- the chewing -Bobject- gums -Iobject- to elliot -Bperson- at the kitchen -Bdestination-',
#  'grasp -Btake- the beer -Bobject- from the dormitory -Bsource- room -Isource-',
#  'bring -Btake- me -Bperson- the blueberries -Bobject-',
#  'give -Btake- the cup -Bobject- to me -Bperson-',
#  'place -Btake- the tablet -Bobject- on the television -Bdestination-',
#  'get -Btake- the pepper -Bobject- from the shed -Bsource- to the closet -Bdestination-',
#  'bring -Btake- the lemons -Bobject- to me -Bperson-',
#  'pick -Btake- up the peach -Bobject- to the room -Bdestination-',
#  'deliver -Btake- the pen -Bobject- to lewis -Bperson-',
#  'grasp -Btake- the cup -Bobject- to the washing -Bdestination- machine -Idestination-',
#  'get -Btake- the chocolate -Bobject bar -Iobject- from the master -Bsource- bedroom -Isource-',
#  'bring -Btake- me -Bperson- the whisky -Bobject- from the drawing -Bsource- room -Isource-',
#  'put -Btake- cider -Bobject- on the living -Bdestination- room -Idestination- table -Idestination-',
#  'grasp -Btake- the sprite -Bobject- from the dryer -Bsource- to the tv -Bdestination- stand -Idestination-',
#  'give -Btake- me -Bperson- the ham -Bobject- burger -Iobject- from the couch -Bsource-',
#  'place -Btake- pear -Bobject- on the fridge -Bdestination-',
#  'take -Btake- the whiteboard -Bobject- cleaner -Iobject- from the sink -Bsource-',
#  'retrieve -Btake- the sprite -Bobject- from the utility -Bsource- room -Isource-',
#  'take -Btake- the lotion -Bobject- to the washing -Bdestination- machine -Idestination-',
#  'give -Btake- to jack -Bperson- at the fridge -Bdestination- the bottle -Bobject- from the dishwasher -Bsource-',
#  'hand -Btake- the banana -Bobject- to oliver -Bperson- at the bedside -Bdestination-',
#  'grasp -Btake- the onion -Bobject-',
#  'put -Btake- the chewing -Bobject- gum -Iobject- to the bathroom -Bdestination-',
#  'get -Btake- the lemons -Bobject- from the corridor -Bsource- to the dryer -Bdestination-',
#  'hand -Btake- the burger -Bobject- to seth -Bperson- at the stove -Bdestination-',
#  'place -Btake- the chocolate -Bobject- tablet -Iobject- on the washing -Bdestination- machine -Idestination-',
#  'bring -Btake- the pencil -Bobject- to alice -Bperson-',
#  'leave -Btake- the chocolate -Bobject- tablet -Iobject- on the bedchamber -Bdestination-',
#  'deliver -Btake- the crackers -Bobject- to me -Bperson-',
#  'deliver -Btake- the chocolate -Bobject- tablet -Iobject- to me -Bperson-',
#  'grasp -Btake- the choco -Bobject- flakes -Iobject- from the bedroom -Bsource-',
#  'bring -Btake- the chewing -Bobject- gums -Iobject- to me -Bperson-',
#  'put -Btake- the paprika -Bobject- to the guestroom -Bdestination-',
#  'pick -Btake- up the trays -Bobject- from the bedroom -Bsource- chair -Isource-',
#  'grasp -Btake- the cookie -Bobject-',
#  'hand -Btake- the onions -Bobject- to jamie -Bperson- at the drawer -Bdestination-',
#  'bring -Btake- the cookies -Bobject- to chloe -Bperson-',
#  'bring -Btake- the tray -Bobject- to florence -Bperson- at the garage -Bdestination-',
#  'take -Btake- the apples -Bobject- to the cabinet -Bdestination-',
#  'deliver -Btake- the container -Bobject- to matthew -Bperson-',
#  'give -Btake- the soap -Bobject- to me -Bperson-',
#  'bring -Btake- the glass -Bobject- to me -Bperson-',
#  'give -Btake- me -Bperson- the blackberries -Bobject- from the laundry -Bsource-',
#  'bring -Btake- the tea -Bobject- to chloe -Bperson- at the cellar -Bdestination-',
#  'grasp -Btake- the biscuit -Bobject- from the coffee -Bsource- table -Isource-',
#  'give -Btake- to mia -Bperson- at the bedside -Bdestination- the knife -Bobject- from the corridor -Bsource-',
#  'retrieve -Btake- the pie -Bobject- from the nightstand -Bsource-',
#  'grasp -Btake- the plates -Bobject-',
#  'pick -Btake- up the donuts -Bobject- from the stove -Bsource-',
#  'deliver -Btake- the tea -Bobject- to me -Bperson-',
#  'deliver -Btake- the tray -Bobject- to elliot -Bperson-',
#  'leave -Btake- the oranges -Bobject- on the rocking -Bdestination- chair -Idestination-',
#  'grasp -Btake- the cream -Bobject-',
#  'hand -Btake- over the wine -Bobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the blueberries -Bobject- from the couch -Bsource-',
#  'hand -Btake- the mints -Bobject- to me -Bperson-',
#  'leave -Btake- food -Bobject- on the bedroom -Bdestination- chair -Idestination-',
#  'get -Btake- the water -Bobject- from the center -Bsource- table -Isource-',
#  'set -Btake- toiletries -Bobject- on the kitchen -Bdestination- cabinet -Idestination-',
#  'leave -Btake- the senbei -Bobject- on the sofa -Bdestination-',
#  'deliver -Btake- the chocolate -Bobject- egg -Iobject- to sophie -Bperson-',
#  'get -Btake- the oranges -Bobject- from the chair -Bsource-',
#  'bring -Btake- the toothbrush -Bobject- to arthur -Bperson-',
#  'grasp -Btake- the pepper -Bobject- from the side -Bsource- table -Isource- to the dishwasher -Bdestination-',
#  'give -Btake- to summer -Bperson- at the nightstand -Bdestination- the onion -Bobject- from the corridor -Bsource-',
#  'take -Btake- the bananas -Bobject- from the shed -Bsource- to the tv -Bdestination- stand -Idestination-',
#  'hand -Btake- over the onions -Bobject- to me -Bperson-',
#  'deliver -Btake- the pear -Bobject- to the sideboard -Bdestination-',
#  'take -Btake- the oranges -Bobject- from the dryer -Bsource- to the corridor -Bdestination-',
#  'take -Btake- the pencil -Bobject- from the closet -Bsource-',
#  'bring -Btake- me -Bperson- the choco -Bobject- flakes -Iobject- from the patio -Bsource-',
#  'bring -Btake- the notebook -Bobject- to charlotte -Bperson- at the lawn -Bdestination-',
#  'place -Btake- soap -Bobject- on the dishwasher -Bdestination-',
#  'get -Btake- the big -Bobject- dish -Iobject- to the washer -Bdestination-',
#  'pick -Btake- up the rice -Bobject- from the master -Bsource- bedroom -Isource- to the couch -Bdestination-',
#  'give -Btake- to olivia -Bperson- at the bookcase -Bdestination- the strawberries -Bobject- from the oven -Bsource-',
#  'take -Btake- the chocolate -Bobject- tablet -Iobject- from the dishwasher -Bsource- to the shed -Bdestination-',
#  'give -Btake- the cake -Bobject- to me -Bperson-',
#  'bring -Btake- to isaac -Bperson- at the kitchen -Bdestination- table -Idestination- the knife -Bobject- from the dishwasher -Bsource-',
#  'take -Btake- the rum -Bobject- from the dishwasher -Bsource- to the closet -Bdestination-',
#  'get -Btake- the ham -Bobject- burger -Iobject- from the corridor -Bsource- to the master -Bdestination- bedroom -Idestination-',
#  'bring -Btake- the vodka -Bobject- to me -Bperson-',
#  'grasp -Btake- the chewing -Bobject- gum -Iobject- to the cloakroom -Bdestination-',
#  'pick -Btake- up the pen -Bobject- to the bedchamber -Bdestination-',
#  'leave -Btake- cereals -Bobject bar -Iobject- on the kitchen -Bdestination- cabinet -Idestination-',
#  'deliver -Btake- the cake -Bobject- to me -Bperson-',
#  'take -Btake- the cup -Bobject- from the entrance -Bsource-',
#  'put -Btake- the charger -Bobject- on the oven -Bdestination-',
#  'get -Btake- the tea -Bobject- from the lamp -Bsource-',
#  'give -Btake- me -Bperson- the book -Bobject-',
#  'bring -Btake- the pear -Bobject- to seth -Bperson-',
#  'deliver -Btake- the glasses -Bobject- to the washer -Bdestination-',
#  'pick -Btake- up the containers -Bobject- to the balcony -Bdestination-',
#  'put -Btake- the choco -Bobject- flakes -Iobject- to the sun -Bdestination- room -Idestination-',
#  'place -Btake- the almonds -Bobject- on the dishwasher -Bdestination-',
#  'place -Btake- the burger -Bobject- on the cabinet -Bdestination-',
#  'pick -Btake- up the chocolate -Bobject- tablet -Iobject- to the workshop -Bdestination-',
#  'set -Btake- ham -Bobject- on the stove -Bdestination-',
#  'leave -Btake- food -Bobject- on the sideboard -Bdestination-',
#  'retrieve -Btake- the grapes -Bobject- from the box -Bsource- room -Isource-',
#  'pick -Btake- up the biscuits -Bobject- to the side -Bdestination- table -Idestination-',
#  'give -Btake- the onion -Bobject- to jamie -Bperson- at the chair -Bdestination-',
#  'give -Btake- the book -Bobject- to me -Bperson-',
#  'pick -Btake- up the apples -Bobject-',
#  'retrieve -Btake- the choco -Bobject- flakes -Iobject- from the den -Bsource-',
#  'place -Btake- toilet -Bobject- paper -Iobject- on the stove -Bdestination-',
#  'bring -Btake- the milk -Bobject- to sarah -Bperson- at the bedchamber -Bdestination-',
#  'take -Btake- the rum -Bobject- to brian -Bperson-',
#  'put -Btake- the biscuits -Bobject- to the patio -Bdestination-',
#  'give -Btake- me -Bperson- the wine -Bobject- from the window -Bsource-',
#  'deliver -Btake- the plate -Bobject- to me -Bperson-',
#  'bring -Btake- the newspaper -Bobject- to tommy -Bperson- at the chair -Bdestination-',
#  'deliver -Btake- the pear -Bobject- to evan -Bperson- at the wardrobe -Bdestination-',
#  'bring -Btake- the sugar -Bobject- to adam -Bperson- at the cellar -Bdestination-',
#  'put -Btake- the cider -Bobject- to the radiator -Bdestination-',
#  'give -Btake- the fork -Bobject- to ryan -Bperson-',
# ...
#  'bring -Btake- to ava -Bperson- at the bedroom -Bdestination- chair -Idestination- the senbei -Bobject- from the tv -Bsource- stand -Isource-',
#  'take -Btake- the laptop -Bobject- to the bookcase -Bdestination-',
#  'pick -Btake- up the chocolate -Bobject bar -Iobject- from the bar -Bsource-',
#  'get -Btake- the shampoo -Bobject- from the side -Bsource- table -Isource- to the drawing -Bdestination- room -Idestination-',
#  'hand -Btake- the candies -Bobject- to me -Bperson-',
#  'bring -Btake- to samantha -Bperson- at the counter -Bdestination- the oranges -Bobject- from the oven -Bsource-',
#  'retrieve -Btake- the rice -Bobject- from the bench -Bsource-',
#  'grasp -Btake- the watermelon -Bobject- from the master -Bsource- bedroom -Isource- to the closet -Bdestination-',
#  'bring -Btake- the paprika -Bobject- to me -Bperson-',
#  'leave -Btake- toothbrush -Bobject- on the kitchen -Bdestination- cabinet -Idestination-',
#  'put -Btake- choco -Bobject- flakes -Iobject- on the television -Bdestination-',
#  'leave -Btake- the bananas -Bobject- on the cabinet -Bdestination-',
#  'hand -Btake- the sponge -Bobject- to blake -Bperson- at the tv -Bdestination- stand -Idestination-',
#  'give -Btake- the beer -Bobject- to abigail -Bperson-',
#  'retrieve -Btake- the chocolate -Bobject- egg -Iobject- from the center -Bsource- table -Isource-',
#  'put -Btake- the rice -Bobject- to the door -Bdestination-',
#  'pick -Btake- up the manju -Bobject- to the nightstand -Bdestination-',
#  'place -Btake- chocolate -Bobject- egg -Iobject- on the cabinet -Bdestination-',
#  'set -Btake- the pizza -Bobject- on the dishwasher -Bdestination-',
#  'pick -Btake- up the food -Bobject- from the oven -Bsource- to the drawing -Bdestination- room -Idestination-',
#  'get -Btake- the apples -Bobject- from the oven -Bsource-',
#  'give -Btake- the beer -Bobject- to me -Bperson-',
#  'get -Btake- the grapes -Bobject- to the bookshelf -Bdestination-',
#  'hand -Btake- the yogurt -Bobject- to grace -Bperson- at the sink -Bdestination-',
#  'leave -Btake- the biscuits -Bobject- on the side -Bdestination- table -Idestination-',
#  'put -Btake- sushi -Bobject- on the stove -Bdestination-',
#  'retrieve -Btake- the peanuts -Bobject- from the nightstand -Bsource-',
#  'pick -Btake- up the glasses -Bobject- from the corridor -Bsource- to the shed -Bdestination-',
#  'bring -Btake- me -Bperson- the sugar -Bobject-',
#  'deliver -Btake- the pen -Bobject- to me -Bperson-',
#  'bring -Btake- me -Bperson- the sugar -Bobject- from the master -Bsource- bedroom -Isource-',
#  'leave -Btake- the newspapers -Bobject- on the kitchen -Bdestination- cabinet -Idestination-',
#  'bring -Btake- to amelia -Bperson- at the sofa -Bdestination- the pen -Bobject- from the dishwasher -Bsource-',
#  'give -Btake- to abigail -Bperson- at the kitchen -Bdestination- cabinet -Idestination- the big -Bobject- dish -Iobject- from the corridor -Bsource-',
#  'put -Btake- manju -Bobject- on the oven -Bdestination-',
#  'give -Btake- me -Bperson- the container -Bobject-',
#  'take -Btake- the chips -Bobject- to the sofa -Bdestination-',
#  'pick -Btake- up the toilet -Bobject- paper -Iobject- to the center -Bdestination- table -Idestination-',
#  'put -Btake- the chocolate -Bobject- egg -Iobject- to the couch -Bdestination-',
#  'put -Btake- ham -Bobject- on the dining -Bdestination- table -Idestination-',
#  'give -Btake- to arthur -Bperson- at the door -Bdestination- the knife -Bobject- from the closet -Bsource-',
#  'take -Btake- the donuts -Bobject- to the oven -Bdestination-',
#  'bring -Btake- me -Bperson- the chewing -Bobject- gums -Iobject-',
#  'hand -Btake- the containers -Bobject- to me -Bperson-',
#  'place -Btake- vodka -Bobject- on the desk -Bdestination-',
#  'deliver -Btake- the pen -Bobject- to william -Bperson- at the sink -Bdestination-',
#  'hand -Btake- over the bread -Bobject- to abigail -Bperson- at the telephone -Bdestination-',
#  'deliver -Btake- the onions -Bobject- to amelie -Bperson-',
#  'set -Btake- toothbrush -Bobject- on the couch -Bdestination-',
#  'get -Btake- the bread -Bobject- from the guestroom -Bsource-',
#  'pick -Btake- up the onion -Bobject- from the dressing -Bsource- table -Isource-',
#  'set -Btake- the vodka -Bobject- on the living -Bdestination- room -Idestination- table -Idestination-',
#  'deliver -Btake- the toothpaste -Bobject- to samantha -Bperson- at the cellar -Bdestination-',
#  'hand -Btake- over the lotion -Bobject- to erika -Bperson- at the stove -Bdestination-',
#  'grasp -Btake- the grapes -Bobject- from the living -Bsource- room -Isource-',
#  'grasp -Btake- the peach -Bobject-',
#  'take -Btake- the salt -Bobject- from the dishwasher -Bsource- to the couch -Bdestination-',
#  'pick -Btake- up the candies -Bobject-',
#  'pick -Btake- up the bread -Bobject- from the oven -Bsource- to the drawing -Bdestination- room -Idestination-',
#  'take -Btake- the drink -Bobject- to charlotte -Bperson-',
#  'deliver -Btake- the pens -Bobject- to the conservatory -Bdestination-',
#  'give -Btake- me -Bperson- the noodles -Bobject- from the lawn -Bsource-',
#  'bring -Btake- me -Bperson- the kleenex -Bobject- from the sink -Bsource-',
#  'grasp -Btake- the newspapers -Bobject- from the coffee -Bsource- table -Isource-',
#  'put -Btake- the strawberries -Bobject- on the bedchamber -Bdestination-',
#  'grasp -Btake- the wine -Bobject- from the dishwasher -Bsource- to the side -Bdestination- table -Idestination-',
#  'deliver -Btake- the bananas -Bobject- to florence -Bperson-',
#  'put -Btake- the rice -Bobject- on the side -Bdestination- table -Idestination-',
#  'take -Btake- the chocolate -Bobject- tablet -Iobject- to sienna -Bperson-',
#  'set -Btake- drink -Bobject- on the stove -Bdestination-',
#  'take -Btake- the banana -Bobject- from the shed -Bsource- to the couch -Bdestination-',
#  'set -Btake- cake -Bobject- on the couch -Bdestination-',
#  'give -Btake- me -Bperson- the chewing -Bobject- gums -Iobject- from the sun -Bsource- room -Isource-',
#  'deliver -Btake- the drink -Bobject- to daniel -Bperson-',
#  'take -Btake- the toilet -Bobject- paper -Iobject- to oscar -Bperson-',
#  'take -Btake- the cereals -Bobject bar -Iobject- to tyler -Bperson-',
#  'bring -Btake- me -Bperson- the blackberries -Bobject- from the larder -Bsource-',
#  'give -Btake- the oranges -Bobject- to brooke -Bperson- at the nightstand -Bdestination-',
#  'deliver -Btake- the cider -Bobject- to louis -Bperson-',
#  'retrieve -Btake- the senbei -Bobject- from the fridge -Bsource-',
#  'hand -Btake- over the whisky -Bobject- to me -Bperson-',
#  'set -Btake- manju -Bobject- on the drawer -Bdestination-',
#  'put -Btake- ham -Bobject- on the stove -Bdestination-',
#  'give -Btake- me -Bperson- the onion -Bobject-',
#  'bring -Btake- the fork -Bobject- to ava -Bperson-',
#  'set -Btake- the peaches -Bobject- on the side -Bdestination- shelf -Idestination-',
#  'get -Btake- the toothpaste -Bobject- to the guestroom -Bdestination-',
#  'give -Btake- the coffee -Bobject- to me -Bperson-',
#  'get -Btake- the vodka -Bobject- from the master -Bsource- bedroom -Isource- to the couch -Bdestination-',
#  'put -Btake- the apples -Bobject- to the den -Bdestination-',
#  'place -Btake- the chocolate -Bobject- egg -Iobject- on the stool -Bdestination-',
#  'retrieve -Btake- the chocolate -Bobject- egg -Iobject- from the bookshelf -Bsource-',
#  'get -Btake- the pencil -Bobject- to the lamp -Bdestination-',
#  'put -Btake- the sprite -Bobject- on the side -Bdestination- shelf -Idestination-',
#  'give -Btake- the yogurt -Bobject- to charles -Bperson- at the bed -Bdestination-',
#  'pick -Btake- up the biscuits -Bobject-',
#  'take -Btake- the pen -Bobject- from the master -Bsource- bedroom -Isource- to the couch -Bdestination-',
#  'bring -Btake- me -Bperson- the pizza -Bobject-',
#  'give -Btake- the pens -Bobject- to oliver -Bperson-',
#  'take -Btake- the candies -Bobject- to joshua -Bperson-',
#  'set -Btake- bottle -Bobject- on the washing -Bdestination- machine -Idestination-',
#  'get -Btake- the cup -Bobject- from the tv -Bsource- stand -Isource-',
#  'retrieve -Btake- the toiletries -Bobject- from the dining -Bsource- table -Isource-',
#  'bring -Btake- the whisky -Bobject- to dylan -Bperson-',
#  'leave -Btake- cans -Bobject- on the counter -Bdestination-',
#  'pick -Btake- up the books -Bobject- to the bathroom -Bdestination-',
#  'hand -Btake- the toilet -Bobject- paper -Iobject- to me -Bperson-',
#  'deliver -Btake- the vodka -Bobject- to emilia -Bperson-',
#  'pick -Btake- up the sake -Bobject- from the chair -Bsource-',
#  'bring -Btake- the sugar -Bobject- to zoe -Bperson-',
#  'give -Btake- me -Bperson- the cake -Bobject- from the sink -Bsource-',
#  'give -Btake- the juice -Bobject- to michael -Bperson- at the cabinet -Bdestination-',
#  'deliver -Btake- the peach -Bobject- to me -Bperson-',
#  'pick -Btake- up the food -Bobject- to the oven -Bdestination-',
#  'get -Btake- the cream -Bobject- from the radiator -Bsource-',
#  'grasp -Btake- the peaches -Bobject-',
#  'hand -Btake- the rum -Bobject- to jackie -Bperson- at the bookcase -Bdestination-',
#  'pick -Btake- up the lotion -Bobject-',
#  'give -Btake- to emma -Bperson- at the closet -Bdestination- the apple -Bobject- from the oven -Bsource-',
#  'bring -Btake- me -Bperson- the pencil -Bobject- from the fridge -Bsource-',
#  'leave -Btake- milk -Bobject- on the coffee -Bdestination- table -Idestination-',
#  'grasp -Btake- the tray -Bobject-',
#  'take -Btake- the pie -Bobject- to the beanbag -Bdestination-',
#  'pick -Btake- up the wine -Bobject- from the oven -Bsource- to the dishwasher -Bdestination-',
#  'hand -Btake- the comb -Bobject- to erika -Bperson- at the cupboard -Bdestination-',
#  'put -Btake- the rice -Bobject- on the oven -Bdestination-',
#  'hand -Btake- over the containers -Bobject- to me -Bperson-',
#  'deliver -Btake- the knife -Bobject- to the side -Bdestination- table -Idestination-',
#  'give -Btake- the apples -Bobject- to me -Bperson-',
#  'hand -Btake- over the grapes -Bobject- to zoe -Bperson- at the room -Bdestination-',
#  'set -Btake- the ham -Bobject- on the sideboard -Bdestination-',
#  'get -Btake- the grapes -Bobject- from the telephone -Bsource-',
#  'give -Btake- the chocolate -Bobject- tablet -Iobject- to me -Bperson-',
#  'bring -Btake- the newspaper -Bobject- to olivia -Bperson-',
#  'set -Btake- the shampoo -Bobject- on the stove -Bdestination-',
#  'give -Btake- me -Bperson- the manju -Bobject-',
#  'hand -Btake- over the knife -Bobject- to me -Bperson-',
#  'pick -Btake- up the bananas -Bobject- to the kitchen -Bdestination- chair -Idestination-',
#  'take -Btake- the ham -Bobject- burger -Iobject- to the bookcase -Bdestination-',
#  'deliver -Btake- the lotion -Bobject- to the games -Bdestination- room -Idestination-',
#  'set -Btake- the vodka -Bobject- on the washing -Bdestination- machine -Idestination-',
#  'get -Btake- the biscuits -Bobject- from the closet -Bsource- to the shed -Bdestination-',
#  'give -Btake- the chips -Bobject- to me -Bperson-',
#  'give -Btake- the whisky -Bobject- to erik -Bperson- at the dishwasher -Bdestination-',
#  'set -Btake- salt -Bobject- on the drawer -Bdestination-',
#  'hand -Btake- over the pencil -Bobject- to grace -Bperson- at the bedroom -Bdestination- chair -Idestination-',
#  'deliver -Btake- the chocolate -Bobject- tablet -Iobject- to me -Bperson-',
#  'grasp -Btake- the book -Bobject- from the drawer -Bsource-',
#  'get -Btake- the orange -Bobject- to the washer -Bdestination-',
#  'bring -Btake- the manju -Bobject- to me -Bperson-',
#  'grasp -Btake- the pie -Bobject- from the sun -Bsource- room -Isource-',
#  'give -Btake- the book -Bobject- to jacob -Bperson- at the center -Bdestination- table -Idestination-',
#  'get -Btake- the vodka -Bobject- to the dressing -Bdestination- table -Idestination-',
#  'bring -Btake- to sophia -Bperson- at the center -Bdestination- table -Idestination- the pen -Bobject- from the dryer -Bsource-',
#  'grasp -Btake- the trays -Bobject- to the dishwasher -Bdestination-',
#  'bring -Btake- the container -Bobject- to paige -Bperson-',
#  'retrieve -Btake- the chewing -Bobject- gums -Iobject- from the prayer -Bsource- room -Isource-',
#  'take -Btake- the lemons -Bobject- from the cabinet -Bsource-',
#  'hand -Btake- the bowl -Bobject- to me -Bperson-',
#  'get -Btake- the magazine -Bobject- to the cupboard -Bdestination-',
#  'retrieve -Btake- the toiletries -Bobject- from the bench -Bsource-',
#  'pick -Btake- up the book -Bobject- from the dishwasher -Bsource- to the side -Bdestination- table -Idestination-',
#  'pick -Btake- up the snacks -Bobject- from the parlour -Bsource-',
#  'pick -Btake- up the kleenex -Bobject- to the center -Bdestination- table -Idestination-',
#  'get -Btake- the pringles -Bobject- from the washer -Bsource-',
#  'grasp -Btake- the orange -Bobject- to the bedchamber -Bdestination-',
#  'set -Btake- juice -Bobject- on the cupboard -Bdestination-',
#  'pick -Btake- up the rum -Bobject-',
#  'hand -Btake- over the container -Bobject- to me -Bperson-',
#  'deliver -Btake- the donuts -Bobject- to noah -Bperson- at the garden -Bdestination-',
#  'leave -Btake- the candies -Bobject- on the nightstand -Bdestination-',
#  'take -Btake- the soap -Bobject- from the box -Bsource- room -Isource-',
#  'bring -Btake- the containers -Bobject- to john -Bperson- at the workshop -Bdestination-',
#  'set -Btake- the towel -Bobject- on the beanbag -Bdestination-',
#  'take -Btake- the plate -Bobject- to charlotte -Bperson-',
#  'give -Btake- the container -Bobject- to william -Bperson-',
#  'take -Btake- the crackers -Bobject- to rosie -Bperson-',
#  'bring -Btake- the burger -Bobject- to emilia -Bperson- at the pantry -Bdestination-',
#  'give -Btake- me -Bperson- the vodka -Bobject-',
#  'bring -Btake- the toothpaste -Bobject- to me -Bperson-',
#  'take -Btake- the lemons -Bobject- to the desk -Bdestination-',
#  'grasp -Btake- the blueberries -Bobject- from the den -Bsource-',
#  'get -Btake- the chewing -Bobject- gums -Iobject- to the bed -Bdestination-',
#  'place -Btake- the choco -Bobject- flakes -Iobject- on the bookshelf -Bdestination-',
#  'grasp -Btake- the cans -Bobject- from the dryer -Bsource- to the dishwasher -Bdestination-',
#  'bring -Btake- the tea -Bobject- to madison -Bperson- at the prayer -Bdestination- room -Idestination-',
#  'deliver -Btake- the shampoo -Bobject- to sarah -Bperson-',
#  'bring -Btake- me -Bperson- the magazine -Bobject- from the desk -Bsource-',
#  'put -Btake- the bread -Bobject- on the bookcase -Bdestination-',
#  'hand -Btake- the pear -Bobject- to evan -Bperson- at the den -Bdestination-',
#  'get -Btake- the toiletries -Bobject- from the music -Bsource- room -Isource-',
#  'bring -Btake- me -Bperson- the whiteboard -Bobject- cleaner -Iobject- from the larder -Bsource-',
#  'grasp -Btake- the container -Bobject- from the tv -Bsource- stand -Isource- to the master -Bdestination- bedroom -Idestination-',
#  'take -Btake- the sugar -Bobject- to ivy -Bperson-',
#  'bring -Btake- me -Bperson- the apple -Bobject- from the oven -Bsource-',
#  'hand -Btake- over the manju -Bobject- to me -Bperson-',
#  'give -Btake- me -Bperson- the newspaper -Bobject- from the fridge -Bsource-',
#  'give -Btake- the cider -Bobject- to ethan -Bperson- at the door -Bdestination-',
#  'deliver -Btake- the yogurt -Bobject- to the conservatory -Bdestination-',
#  'deliver -Btake- the cake -Bobject- to the side -Bdestination- table -Idestination-',
#  'get -Btake- the blackberries -Bobject- to the dressing -Bdestination- table -Idestination-',
#  'bring -Btake- the sugar -Bobject- to rosie -Bperson-',
#  'pick -Btake- up the sake -Bobject- from the staircase -Bsource-',
#  'place -Btake- orange -Bobject- on the kitchen -Bdestination- cabinet -Idestination-',
#  'pick -Btake- up the cup -Bobject-',
#  'hand -Btake- over the glass -Bobject- to michael -Bperson- at the dormitory -Bdestination- room -Idestination-',
#  'put -Btake- the salt -Bobject- on the bedchamber -Bdestination-',
#  'pick -Btake- up the milk -Bobject- to the lamp -Bdestination-',
#  'deliver -Btake- the magazine -Bobject- to lucy -Bperson- at the cabinet -Bdestination-',
#  'put -Btake- the pepper -Bobject- to the center -Bdestination- table -Idestination-',
#  ...]

# %% [markdown]
# # Adding Intro

# %%
# ################################################################################################################
#                                           ADDING INTRO (eg: hello, robot)                                      #
# ################################################################################################################

# Appending introductions (eg: "hello robot" , "could you please" etc.) and generating inputs and outputs
c = 0
sentences = []
outputs = []
for v in range(len(tasks)):

    try:
        task = tasks[v].split(' ')
    except:
        print('error at {}, check if the items in tasks are strings tasks[v] = {}'.format(v, tasks[v]))
        break

    intro = intros[c].split(' ')

    sentence = []
    output = []
    # appending intro if the total length is less than or equal to 15 (ref: Pedro master thesis)
    task_with_intro = []
    if v%4 == 0 and (len(intro) + len(task)) <= 15:
        for x in intro:
            task_with_intro.append(x)
        c = c + 1

    # reinitiating intros
    if c == len(intros):
        c = 0

    # appending task
    for x in task:
        task_with_intro.append(x)

    # appending the task with introduction to the sentence list
    for h in range(len(task_with_intro)):
        if not task_with_intro[h].startswith('-'):
            sentence.append(task_with_intro[h])
            # appending outputs according to the input
            if h < len(task_with_intro)-1:
                if task_with_intro[h+1].startswith('-'):
                    l = task_with_intro[h+1]
                    l = l.replace('-', '')
                    output.append(l)
                else:
                    output.append('O')
            else:
                output.append('O')
    # split sentences and tags
    sentences.append(sentence)
    outputs.append(output)

# %% [markdown]
# # Msgpack Dump

# %%
sentences_dict = {i:" ".join(lst) for i,lst in enumerate(sentences)}
outputs_dict = {i:" ".join(lst) for i,lst in enumerate(outputs)}

# %%
import pandas as pd

# %%
com_df = pd.DataFrame.from_dict(sentences_dict,orient = 'index', columns = ['Commands'])
lab_df = pd.DataFrame.from_dict(outputs_dict,orient = 'index', columns = ['Labels'])

# %%
df_merged = pd.concat([com_df,lab_df],axis=1,ignore_index=True)
df_merged
# Out:
#                                                 0  \
# 0                      robot hand the cloth to me
# 1                      set the sugar on the stool
# 2              bring me the book from the parlour
# 3          deliver the bread to faith at the door
# 4      hello robot take the forks to the bathroom
# ...                                           ...
# 54995                        lead toby to the bed
# 54996         please usher abigail to the bedside
# 54997                  lead amelie to the library
# 54998      escort isabelle to the washing machine
# 54999                  oversee lewis to the stool
#
#                                                 1
# 0                     O Btake O Bobject O Bperson
# 1                Btake O Bobject O O Bdestination
# 2             Btake Bperson O Bobject O O Bsource
# 3      Btake O Bobject O Bperson O O Bdestination
# 4            O O Btake O Bobject O O Bdestination
# ...                                           ...
# 54995                  O Bperson O O Bdestination
# 54996                O O Bperson O O Bdestination
# 54997                  O Bperson O O Bdestination
# 54998     O Bperson O O Bdestination Idestination
# 54999                  O Bperson O O Bdestination
#
# [55000 rows x 2 columns]

# %% [markdown]
# # Save

# %%
# ################################################################################################################
#                                                  MSGPACK DUMP                                                  #
# ################################################################################################################

# # pickling inputs and labels
# with open('inputs_slot_filling', 'wb') as inputs_file:
#     msgpack.dump(sentences, inputs_file)

# with open('outputs_slot_filling', 'wb') as outputs_file:
#     msgpack.dump(outputs, outputs_file)

import json
with open('inputs_slot_filling.json', "w") as jsonfile:
    json.dump(sentences_dict, jsonfile)
    
    
with open('outputs_slot_filling.json', "w") as jsonfile:
    json.dump(outputs_dict, jsonfile)

# %% [markdown]
# # User Feedback

# %%
# ################################################################################################################
#                                                  USER FEEDBACK                                                 #
# ################################################################################################################

print('Total number of inputs', len(sentences))
print('Total number of outputs', len(outputs))
print('-----------------------------------------------------')
print('Data generation is complete for Slots training, you may start the training by running training_nn_model.py script')
